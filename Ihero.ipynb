# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
import pprint

# %%
def get_brands_urls(main_url="https://ihero.dk/priser/"):
    html = urlopen(main_url)
    soup = BeautifulSoup(html, "html.parser")
    # we extract the urls corresponding to each of the phones on the page of the brand
    urls = {}
    brand_soups = soup.find_all("a", class_="col m:w1/1 brand-box")
    n=0
    while True:
        try:
            brand = brand_soups[n].find("span", class_="brand-box-title").contents[0].replace("Reparation af", "").strip()
            url = brand_soups[n].get("href")
            
            if brand in ["iPhones", "iPads", "Mac"]:
                brand="Apple" + " " + brand
            elif brand in ["PCer"]:
                brand="PC"
            
            urls[brand] = url
            n+=1

        except:
            break
    return urls

# get_brands_urls()

# %%
def get_series_urls(brand_name, brand_url):
    html = urlopen(brand_url)
    soup = BeautifulSoup(html, "html.parser")
    series_soups = soup.find_all("a", class_="col m:w1/1 brand-box")
    series_urls = {}
    for serie_soup in series_soups:
        serie_name = serie_soup.find("span", class_="brand-box-title").contents[0]
        url = serie_soup.get("href")
        serie_name = serie_name.replace("-Serien", "").strip()
        series_urls[serie_name] = url
    return series_urls

# get_series_urls('Samsung', 'https://ihero.dk/samsung-reparation/')

# %%
def get_phone_serie_reparations(brand_name, serie_name, serie_url):
    html = urlopen(serie_url)
    soup = BeautifulSoup(html, "html.parser")
    reparation_names = [rep.contents[0] for rep in soup.find_all("td", class_="rep-title")]
    prices =  [price.contents[0] for price in soup.find_all("td", class_="price-field tilbuds-pris")]
    
    serie_dict = {}    
    
    for reparation_name, price in zip(reparation_names, prices):
        
        # convert price to float
        price = float(price.replace(",-", "").strip())
        
        reparation_dict = {}
        
        # for each of the reparation names, we check if several models are described in one line
        if serie_name != "Diverse Modeller":
            reparation_name_split = reparation_name.split(serie_name)
        else:
            reparation_name_split = [""]
        
        if len(reparation_name_split[0]) > 0:
            # several models described in one line
            phone_names = [(serie_name + x.strip()).replace(serie_name[-1] + serie_name[-1], serie_name[-1]) for x in reparation_name_split[1].split(",")]
            
            for phone_name in phone_names:
                
                phone_name = (brand_name + " " + phone_name).strip()
                # print(phone_name, "\t", reparation_name, "\t", price)

        else:
            phone_name = reparation_name.replace("Komplet skærm udskiftning", "")\
                                        .replace("Komplet Skærm Udskiftning", "")\
                                        .replace("LCD Udskiftning", "")\
                                        .replace("Glas Udskiftning", "")
            # print(phone_name, "\t", reparation_name, "\t", price)
            # phone_name = re.search(serie_name + "(\d{0,2})?.?\s?(\((PLUS )?\d{4}\))?(lpha|Plus|PLUS|Mini|Edge|Active|Duos|Neo|Advance)?(\s?\+)?", reparation_name).group(0)
            phone_name = (brand_name + " " + phone_name).strip()
            reparation_name = reparation_name.replace(phone_name, "") 
        # print(serie_dict)
        if phone_name in serie_dict:
            serie_dict[phone_name][reparation_name] = price
        else:
            reparation_dict[reparation_name] = price
            serie_dict[phone_name] = reparation_dict

    # print(serie_dict)    
    return serie_dict

# for serie, url in get_series_urls('Samsung', 'https://ihero.dk/samsung-reparation/').items():
#     get_phone_serie_reparations('Samsung', serie, url)

# %%
def get_phones_urls(brand_name, brand_url):
    html = urlopen(brand_url)
    soup = BeautifulSoup(html, "html.parser")
    phones_soups = soup.find_all("a", class_="col m:w1/1 brand-box")
    phone_names_urls = {}
    for phone_soup in phones_soups:
        phone_name = phone_soup.find("span", class_="brand-box-title").contents[0]
        url = phone_soup.get("href")
        phone_name = brand_name + " " + phone_name
        phone_names_urls[phone_name] = url
    return phone_names_urls

# get_phones_urls("Apple iPhones", "https://ihero.dk/iphone-reparation-2/")

# %%
def get_phone_reparations(phone_url):
    html = urlopen(phone_url)
    soup = BeautifulSoup(html, "html.parser")
    reparation_names = [x.contents[0] for x in soup.find_all("td", class_="rep-title")]
    prices = [x.contents[0] for x in soup.find_all("td", class_="price-field tilbuds-pris")]
    phone_dict = {}
    for (reparation_name, price) in zip(reparation_names, prices):
        # convert price to float
        price = float(price.replace(",-", "").replace('IKKE PÅ LAGER', "NaN").replace("GRATIS", "0").strip())
        phone_dict[reparation_name] = price
    return phone_dict

# get_phone_reparations("https://ihero.dk/iphone-11-pro-max-reparation/")

# %%
brand_urls_dict = get_brands_urls()

repair_cost_dict = {}
for brand, brand_url in brand_urls_dict.items():
    if brand == "Samsung":
        print(brand, brand_url)
        for serie, url in get_series_urls('Samsung', 'https://ihero.dk/samsung-reparation/').items():
            serie_dict = get_phone_serie_reparations('Samsung', serie, url)
            for phone_item in serie_dict.items():
                phone_name = phone_name = phone_item[0]
                reparations_dict = phone_item[1]
                repair_cost_dict[phone_name] = get_phone_reparations(phone_url)
    else:
        
        print(brand, brand_url)
        phone_urls_dict = get_phones_urls(brand, brand_url)
        for phone_item in phone_urls_dict.items():
            phone_name = phone_item[0]
            phone_url = phone_item[1]
            repair_cost_dict[phone_name] = get_phone_reparations(phone_url)
print("done")
# Out:
# Apple iPhones https://ihero.dk/iphone-reparation-2/
# Apple iPads https://ihero.dk/ipad-reparation/
# Apple Mac https://ihero.dk/mac-reparation/
# Huawei https://ihero.dk/huawei/
# Sony https://ihero.dk/sony-reparation/
# One Plus https://ihero.dk/one-plus/
# LG https://ihero.dk/lg-reparation/
# Nokia https://ihero.dk/nokia-reparation/
# PC https://ihero.dk/pc-reparation/
# done
# {'Apple iPhones IPhone 11 Pro Max': {'Skærm udskiftning': 2399.0,
#   'Skærm beskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1500.0,
#   'Batteri udskiftning': nan},
#  'Apple iPhones iPhone 11 Pro': {'Skærm Udskiftning': 1999.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1500.0,
#   'Batteri Udskiftning': nan},
#  'Apple iPhones iPhone 11': {'Skærm udskiftning (OEM)': 1199.0,
#   'Skærm beskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1500.0,
#   'Batteri Udskiftning': nan},
#  'Apple iPhones iPhone XS Max': {'Skærm udskiftning (Grade A+++)': 1499.0,
#   'Skærm udskiftning (OEM)': 2999.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1000.0,
#   'Batteri udskiftning': 999.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 1200.0,
#   'Kameralinse udskiftning': 799.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone XS': {'Skærm udskiftning (Grade A+++)': 1349.0,
#   'Skærm udskiftning (OEM)': 2499.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 900.0,
#   'Batteri udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 1200.0,
#   'Kameralinse udskiftning': 799.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone XR': {'Skærm udskiftning (Grade A+++)': 799.0,
#   'Skærm udskiftning (OEM)': 1699.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 900.0,
#   'Batteri udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 999.0,
#   'Kameralinse udskiftning': 799.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone X': {'Skærm udskiftning (Grade A+++)': 1099.0,
#   'Skærm udskiftning (OEM)': 2199.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 900.0,
#   'Batteri udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 1200.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Kameralinse udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 8 Plus': {'Skærm udskiftning': 699.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 800.0,
#   'Batteri udskiftning': 399.0,
#   'Ladestik udskiftning': 699.0,
#   'Mikrofon udskiftning': 699.0,
#   'Ørehøjtaler udskiftning': 699.0,
#   'Bundhøjtaler udskiftning': 699.0,
#   'Front kamera udskiftning': 699.0,
#   'Bagkamera udskiftning': 699.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 699.0,
#   'Volume/Lydløs Funktion udskiftning': 699.0,
#   'Vibrator udskiftning': 699.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 8': {'Skærm udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 800.0,
#   'Batteri udskiftning': 399.0,
#   'Ladestik udskiftning': 599.0,
#   'Mikrofon udskiftning': 599.0,
#   'Ørehøjtaler udskiftning': 599.0,
#   'Bundhøjtaler udskiftning': 599.0,
#   'Front kamera udskiftning': 599.0,
#   'Bagkamera udskiftning': 599.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 599.0,
#   'Volume/Lydløs Funktion udskiftning': 599.0,
#   'Vibrator udskiftning': 599.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 7 Plus': {'Skærm udskiftning': 449.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 399.0,
#   'Bundhøjtaler udskiftning': 399.0,
#   'Ladestik udskiftning': 499.0,
#   'Mikrofon udskiftning': 499.0,
#   'Volume/Lydløs Funktion udskiftning': 649.0,
#   'Tænd/Sluk funktion (Powerknap) udskiftning': 649.0,
#   'Front kamera udskiftning': 499.0,
#   'Bagkamera udskiftning': 749.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 7': {'Skærm udskiftning': 449.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 399.0,
#   'Bundhøjtaler udskiftning': 399.0,
#   'Mikrofon udskiftning': 449.0,
#   'Volume/Lydløs Funktion udskiftning': 649.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 649.0,
#   'Ladestik udskiftning': 449.0,
#   'Front kamera udskiftning': 399.0,
#   'Bagkamera udskiftning': 499.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6S Plus': {'Skærm udskiftning': 499.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 349.0,
#   'Bundhøjtaler udskiftning': 349.0,
#   'Mikrofon udskiftning': 349.0,
#   'Volume/Lydløs funktion udskiftning': 449.0,
#   'Jackstik udskiftning': 349.0,
#   'Home Knap udskiftning': 349.0,
#   'Tænd/Sluk funktion udskiftning': 449.0,
#   'Ladestik udskiftning': 349.0,
#   'Front Kamera udskiftning': 349.0,
#   'Bagkamera udskiftning': 449.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6S': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 349.0,
#   'Mikrofon udskiftning': 349.0,
#   'Jackstik udskiftning': 349.0,
#   'Ørehøjtaler udskiftning': 349.0,
#   'Bundhøjtaler udskiftning': 349.0,
#   'Volume/Lydløs funktion udskiftning': 449.0,
#   'Tænd/Sluk funktion udskiftning': 449.0,
#   'Home Knap udskiftning': 349.0,
#   'Front Kamera udskiftning': 349.0,
#   'Bagkamera udskiftning': 349.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6 Plus': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 349.0,
#   'Bundhøjtaler udskiftning': 349.0,
#   'Mikrofon udskiftning': 349.0,
#   'Volume/Lydløs funktion udskiftning': 449.0,
#   'Jackstik udskiftning': 349.0,
#   'Home Knap udskiftning': 349.0,
#   'Tænd/Sluk funktion udskiftning': 449.0,
#   'Ladestik udskiftning': 349.0,
#   'Front Kamera udskiftning': 349.0,
#   'Bagkamera udskiftning': 349.0,
#   'Kameralinse udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6': {'Skærm udskiftning': 349.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Volume/Lydløs funktion udskiftning': 399.0,
#   'Tænd/Sluk funktion udskiftning': 399.0,
#   'Home Knap udskiftning': 299.0,
#   'BagKamera udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Kameralinse udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone SE 2020': {'Skærm udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1000.0,
#   'Batteri udskiftning': 499.0,
#   'Ladestik udskiftning': 599.0,
#   'Mikrofon udskiftning': 599.0,
#   'Ørehøjtaler udskiftning': 400.0,
#   'Bundhøjtaler udskiftning': 599.0,
#   'Front kamera udskiftning': 700.0,
#   'Bagkamera udskiftning': 700.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 800.0,
#   'Volume/Lydløs Funktion udskiftning': 800.0,
#   'Vibrator udskiftning': 400.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone SE': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 5S': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 5C': {'Skærm udskiftning': 299.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 5': {'Skærm udskiftning': 299.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Vibrator udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 4/4S': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 100.0,
#   'Batteri udskiftning': 199.0,
#   'Home knap udskiftning': 250.0,
#   'Andre knapper udskiftning': 250.0,
#   'Mikrofon udskiftning': 225.0,
#   'Front Kamera udskiftning': 200.0,
#   'Bagkamera udskiftning': 250.0,
#   'Ladestik udskiftning': 225.0,
#   'Vibrator udskiftning': 200.0,
#   'Jackstik udskiftning': 250.0,
#   'Antenne udskiftning': 220.0,
#   'Ramme udskiftning': 350.0,
#   'WIFI-antenne udskiftning': 220.0,
#   'Ørehøjtaler udskiftning': 200.0,
#   'Bundhøjtaler udskiftning': 200.0,
#   'Diagnose': 0.0},
#  'Apple iPads IPad 2': {'Glas udskiftning': 299.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 499.0,
#   'Batteri udskiftning': 549.0,
#   'Jackstik udskiftning': 499.0,
#   '3G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 499.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Home knap udskiftning': 499.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad 3': {'Glas udskiftning': 349.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 599.0,
#   'Jackstik udskiftning': 499.0,
#   '3G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 499.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Batteri udskiftning': 649.0,
#   'Home knap udskiftning': 499.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad 4': {'Glas udskiftning': 349.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 599.0,
#   'Batteri udskiftning': 649.0,
#   'Jackstik udskiftning': 499.0,
#   '3G/4G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 499.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Home knap udskiftning': 499.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Air': {'Glas udskiftning': 399.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 799.0,
#   'Jackstik udskiftning': 649.0,
#   '3G/4G-antenne udskiftning': 649.0,
#   'WIFI-antenne udskiftning': 649.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 649.0,
#   'Volume/lydløs/power-knap udskiftning': 649.0,
#   'Batteri udskiftning': 649.0,
#   'Home knap udskiftning': 649.0,
#   'Bluetooth-antenne udskiftning': 649.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Air 2': {'Skærm udskiftning': 1249.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 899.0,
#   'Jackstik udskiftning': 699.0,
#   '3G/4G-antenne udskiftning': 699.0,
#   'WIFI-antenne udskiftning': 699.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 699.0,
#   'Volume/lydløs/power-knap udskiftning': 699.0,
#   'Home knap udskiftning': 699.0,
#   'Bluetooth-antenne udskiftning': 699.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Air 2019': {'Skærm Udskiftning': 1799.0},
#  'Apple iPads iPad 9,7 2017': {'Glas udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 999.0,
#   'Jackstik udskiftning': 799.0,
#   '3G/4G-antenne udskiftning': 799.0,
#   'WIFI-antenne udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 799.0,
#   'Volume/lydløs/power-knap udskiftning': 799.0,
#   'Batteri udskiftning': 799.0,
#   'Home knap udskiftning': 799.0,
#   'Bluetooth-antenne udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad 9,7 2018': {'Glas udskiftning': 699.0,
#   'LCD udskiftning': 999.0,
#   'Batteri udskiftning': 599.0,
#   'Ladestik udskiftning': 999.0},
#  'Apple iPads iPad Mini 1-2': {'Glas udskiftning': 499.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 699.0,
#   'Batteri udskiftning': 699.0,
#   'Jackstik udskiftning': 499.0,
#   '3G/4G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Home knap udskiftning': 699.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Mini 3': {'Glas udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 699.0,
#   'Batteri udskiftning': 699.0,
#   'Jackstik udskiftning': 699.0,
#   '3G/4G-Antenne udskiftning': 699.0,
#   'WIFI-Antenne udskiftning': 699.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 699.0,
#   'Volume/lydløs/power-knap udskiftning': 699.0,
#   'Home knap udskiftning': 699.0,
#   'Bluetooth-antenne udskiftning': 699.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Mini 4': {'Skærm udskiftning': 1399.0,
#   'Skærmbeskyttelse': 200.0,
#   'Bagcover udskiftning': 1499.0,
#   'Jackstik udskiftning': 749.0,
#   '3G/4G-Antenne udskiftning': 749.0,
#   'WIFI-Antenne udskiftning': 749.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 749.0,
#   'Volume/lydløs/power-knap udskiftning': 749.0,
#   'Batteri udskiftning': 749.0,
#   'Home knap udskiftning': 749.0,
#   'Bluetooth-antenne udskiftning': 749.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Mini 2019': {'Skærm Udskiftning': 1499.0},
#  'Apple iPads iPad PRO': {},
#  'Apple iPads iPad 10,2 2019': {'Skærm Udskiftning': 899.0},
#  'Apple Mac Macbook Pro': {},
#  'Apple Mac Macbook Pro Retina': {},
#  'Apple Mac MacBook Air 11"': {},
#  'Apple Mac MacBook Air 13"': {},
#  'Apple Mac iMac': {},
#  'Apple Mac iMac Retina/4K/5K': {},
#  'Apple Mac Macbook Pro (Uden Touch Bar)': {},
#  'Apple Mac Macbook Pro (Med Touch Bar)': {},
#  'Apple Mac Macbook 12"': {},
#  'Huawei Huawei P30 Pro': {'Udskiftning af skærm': 2800.0},
#  'Huawei Huawei P30': {'Udskiftning af skærm': 1299.0},
#  'Huawei Huawei P30 Lite': {'Udskiftning af skærm': 999.0},
#  'Huawei Huawei Mate 20 Pro': {'Udskiftning af skærm': 3499.0},
#  'Huawei Huawei P20 Pro': {'Glas/LCD - Udskiftning': 2300.0,
#   'Bagside - Udskiftning': 699.0,
#   'Batteri - Udskiftning': nan},
#  'Huawei Huawei Mate 20 Lite': {'Udskiftning af skærm': 1500.0},
#  'Huawei Huawei P20 Lite': {'Glas/LCD - Udskiftning': 799.0,
#   'Bagside - Udskiftning': 599.0,
#   'Batteri - Udskiftning': 499.0},
#  'Huawei Huawei P20': {'Glas/LCD - Udskiftning': 899.0,
#   'Bagside - Udskiftning': 599.0},
#  'Huawei Huawei Mate 10 Pro': {'Glas/LCD - Udskiftning': 2499.0},
#  'Huawei Huawei Mate 9 Pro': {'Glas/LCD - Udskiftning': 3000.0},
#  'Huawei Huawei P10 Plus': {'Glas/LCD - Udskiftning': 1400.0,
#   'Bagside - Udskiftning': 1000.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P9 Plus': {'Glas/LCD - Udskiftning': 1700.0,
#   'Bagside - Udskiftning': 700.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P10 Lite': {'Glas/LCD - Udskiftning': 799.0,
#   'Bagside - Udskiftning': 500.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P10': {'Glas/LCD - Udskiftning': 949.0,
#   'Bagside - Udskiftning': 700.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei Mate 10 Lite': {'Glas/LCD - Udskiftning': 799.0},
#  'Huawei Huawei Mate 10': {'Glas/LCD - Udskiftning': 1099.0},
#  'Huawei Huawei P9 Lite': {'Glas/LCD - Udskiftning': 749.0,
#   'Bagside - Udskiftning': 500.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P9': {'Glas/LCD - Udskiftning': 899.0,
#   'Bagside - Udskiftning': 600.0,
#   'Batteri - Udskiftning': 600.0},
#  'Huawei Huawei Honor 9 Lite': {'Glas/LCD - Udskiftning': 849.0},
#  'Huawei Huawei Honor 9': {'Glas/LCD - Udskiftning': 1699.0},
#  'Huawei Huawei P8 Lite': {'Glas/LCD - Udskiftning': 750.0,
#   'Bagside - Udskiftning': 500.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P8': {'Glas/LCD - Udskiftning': 750.0,
#   'Bagside Udskiftning': 500.0,
#   'Batteri Udskiftning': 500.0},
#  'Huawei Huawei P Smart 2019': {'Udskiftning af skærm': 899.0},
#  'Huawei Huawei P-Smart': {'Udskiftning af skærm': 799.0},
#  'Huawei Huawei Y6 2019': {'Udskiftning af skærm': 1000.0},
#  'Huawei Huawei Y5 2019': {'Udskiftning af skærm': 1100.0},
#  'Huawei Huawei P Smart Z': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S8': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S6': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S10 Plus': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S10 Komplet skærm Udskiftning': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S10E Komplet skærm Udskiftning': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S9 PLUS': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S9': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S8 PLUS': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S7 Edge': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S7': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S6 Edge +': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S6 Edge': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5 Mini': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5 Neo': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5 Active': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4 +': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4 Mini': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4 Active': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S3 Mini': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S +': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S Advance': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S Duos': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 10': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 9': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 8': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 2/4G LTE': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note Edge': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover 2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover 3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover 4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A80': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A70': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A50': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A40': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A20E': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A10': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A9 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A8 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A6 (PLUS 2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A6 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A5 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A5 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A3 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A3 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Alpha': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace Plus': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace Style': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace 2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace 3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace 4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J7 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J7 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J5 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J5 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy W': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy R': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Omnia': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Mega': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J1': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Express 2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Express': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Grand 2 Duos': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Core Prime': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Core Plus': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ativ S': {'Udskiftning af skærm': 1300.0},
#  'Sony Xperia Z5 Premium': {'Komplet Skærm Udskiftning': 2000.0},
#  'Sony Xperia Z5 Compact': {'Glas/LCD': 1199.0, 'BAGSIDE': 500.0},
#  'Sony Xperia Z5': {'GLAS/LCD': 1500.0, 'BAGSIDE': 500.0},
#  'Sony Xperia Z4 (Z3+)': {'GLAS/LCD': 1499.0, 'Bagside': 500.0},
#  'Sony Xperia Z3 Compact': {'Glas/LCD': 999.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z3': {'Glas/LCD': 1199.0, 'Bagside': 399.0, 'Diagnose': 0.0},
#  'Sony Xperia Z2': {'Glas/LCD': 999.0, 'Bagside': 399.0, 'Diagnose': 0.0},
#  'Sony Xperia Z1 Compact': {'Glas/LCD': 800.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z1': {'Komplet LCD + glas': 849.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z': {'Komplet LCD + glas': 849.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z Ultra': {'Komplet Skærm Udskiftning': 2200.0},
#  'Sony Diverse Modeller': {'Xperia Go Komplet Skærm Udskiftning': 1000.0,
#   'Xperia E4 Komplet Skærm Udskiftning': 800.0,
#   'Xperia U Glas Udskiftning': 600.0},
#  'Sony X-Serien': {'Xperia X Performance Komplet Skærm Udskiftning': 1800.0,
#   'Xperia X Performance Dual Komplet Skærm Udskiftning': 1800.0,
#   'Xperia X Komplet Skærm Udskiftning': 1500.0,
#   'Xperia XA Komplet Skærm Udskiftning': 1000.0,
#   'Xperia XA1 Komplet Skærm Udskiftning': 1100.0,
#   'Xperia XA Dual Komplet Skærm Udskiftning': 1000.0},
#  'Sony M-Serie': {'Xperia M Glas Udskiftning': 700.0,
#   'Xperia M2 Glas Udskiftning': 800.0,
#   'Xperia M2 Aqua Komplet Skærm Udskiftning': 1000.0,
#   'Xperia M4 Aqua Komplet Skærm Udskiftning': 1000.0,
#   'Xperia M5 Komplet Skærm Udskiftning': 1200.0},
#  'One Plus OnePlus 7 Pro': {'Skærm Udskiftning': 3500.0},
#  'One Plus OnePlus 7': {'Skærm Udskiftning': 2500.0},
#  'One Plus OnePlus 6T': {'Skærm Udskiftning': 2000.0, 'Bagside': 700.0},
#  'One Plus OnePlus 6': {'Skærm Udskiftning': 1799.0, 'Bagside': 699.0},
#  'One Plus OnePlus 5T': {'Skærm Udskiftning': 1399.0,
#   'Batteri Udskiftning': 700.0},
#  'One Plus OnePlus 5': {'Skærm Udskiftning': 1199.0,
#   'Batteri Udskiftning': 600.0},
#  'One Plus OnePlus 3T': {'Skærm Udskiftning': 1249.0,
#   'Batteri Udskiftning': 600.0},
#  'One Plus OnePlus 3': {'GLAS/LCD': 1249.0},
#  'One Plus OnePlus 2': {'GLAS/LCD': 849.0, 'Diagnose': 0.0},
#  'One Plus OnePlus One': {'GLAS/LCD': 849.0,
#   'Ladestik': 600.0,
#   'Diagnose': 0.0},
#  'One Plus OnePlus X': {'GLAS/LCD': 1199.0},
#  'LG LG G6': {'Glas/LCD Udskiftning': 1500.0},
#  'LG LG G5': {'Komplet Skærm Udskiftning': 2000.0},
#  'LG LG G4S': {'Komplet Skærm Udskiftning': 1000.0},
#  'LG LG G4': {'GLAS/LCD': 1100.0, 'Diagnose': 0.0},
#  'LG LG G3S': {'Glas Udskiftning': 800.0},
#  'LG LG G3': {'GLAS/LCD': 1000.0, 'Diagnose': 0.0},
#  'LG LG G2': {'Skærm/LCD': 950.0, 'Diagnose': 0.0},
#  'LG LG G2 MINI': {'GLAS': 700.0, 'LCD': 900.0, 'Diagnose': 0.0},
#  'LG LG Nexus 5X': {'Komplet Skærm Udskiftning': 1200.0},
#  'LG LG (GOOGLE) NEXUS 5': {'Komplet LCD + glas': 1200.0, 'Diagnose': 0.0},
#  'LG LG (GOOGLE) NEXUS 4': {'Skærm/LCD': 1100.0, 'Diagnose': 0.0},
#  'LG LG G FLEX 2': {'GLAS/LCD': 1800.0, 'Diagnose': 0.0},
#  'LG LG G Flex': {'Glas/LCD': 1700.0, 'Diagnose': 0.0},
#  'LG LG OPTIMUS G': {'Skærm/LCD': 950.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 1520': {'Glas/LCD': 1200.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 1320': {'Glas/LCD': 1500.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 1020': {'Glas/LCD': 1000.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 935': {'Glas/LCD': 1800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 930': {'Glas/LCD': 1800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 920': {'Glas/LCD': 1200.0, 'Glas': 600.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 900': {'Komplet LCD + glas': 1200.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 830': {'Glas/LCD': 1600.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 820': {'LCD': 900.0,
#   'Glas': 700.0,
#   'Komplet LCD + glas': 1200.0,
#   'Diagnose': 0.0},
#  'Nokia Nokia Lumia 800': {'Komplet LCD + glas': 800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 735': {'Glas/LCD': 800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 730': {'Glas/ LCD': 800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 720': {'Glas/LCD': 1200.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 710': {'Glas': 800.0, 'LCD': 800.0, 'Diagnose': 0.0}}

# %%
repair_cost_dict
# Out:
# {'Apple iPhones IPhone 11 Pro Max': {'Skærm udskiftning': 2399.0,
#   'Skærm beskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1500.0,
#   'Batteri udskiftning': nan},
#  'Apple iPhones iPhone 11 Pro': {'Skærm Udskiftning': 1999.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1500.0,
#   'Batteri Udskiftning': nan},
#  'Apple iPhones iPhone 11': {'Skærm udskiftning (OEM)': 1199.0,
#   'Skærm beskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1500.0,
#   'Batteri Udskiftning': nan},
#  'Apple iPhones iPhone XS Max': {'Skærm udskiftning (Grade A+++)': 1499.0,
#   'Skærm udskiftning (OEM)': 2999.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1000.0,
#   'Batteri udskiftning': 999.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 1200.0,
#   'Kameralinse udskiftning': 799.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone XS': {'Skærm udskiftning (Grade A+++)': 1349.0,
#   'Skærm udskiftning (OEM)': 2499.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 900.0,
#   'Batteri udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 1200.0,
#   'Kameralinse udskiftning': 799.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone XR': {'Skærm udskiftning (Grade A+++)': 799.0,
#   'Skærm udskiftning (OEM)': 1699.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 900.0,
#   'Batteri udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 999.0,
#   'Kameralinse udskiftning': 799.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone X': {'Skærm udskiftning (Grade A+++)': 1099.0,
#   'Skærm udskiftning (OEM)': 2199.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 900.0,
#   'Batteri udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Mikrofon udskiftning': 999.0,
#   'Ørehøjtaler udskiftning': 799.0,
#   'Bundhøjtaler udskiftning': 799.0,
#   'Front kamera udskiftning': 999.0,
#   'Bagkamera udskiftning': 1200.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 999.0,
#   'Volume/Lydløs Funktion udskiftning': 999.0,
#   'Vibrator udskiftning': 799.0,
#   'Kameralinse udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 8 Plus': {'Skærm udskiftning': 699.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 800.0,
#   'Batteri udskiftning': 399.0,
#   'Ladestik udskiftning': 699.0,
#   'Mikrofon udskiftning': 699.0,
#   'Ørehøjtaler udskiftning': 699.0,
#   'Bundhøjtaler udskiftning': 699.0,
#   'Front kamera udskiftning': 699.0,
#   'Bagkamera udskiftning': 699.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 699.0,
#   'Volume/Lydløs Funktion udskiftning': 699.0,
#   'Vibrator udskiftning': 699.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 8': {'Skærm udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 800.0,
#   'Batteri udskiftning': 399.0,
#   'Ladestik udskiftning': 599.0,
#   'Mikrofon udskiftning': 599.0,
#   'Ørehøjtaler udskiftning': 599.0,
#   'Bundhøjtaler udskiftning': 599.0,
#   'Front kamera udskiftning': 599.0,
#   'Bagkamera udskiftning': 599.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 599.0,
#   'Volume/Lydløs Funktion udskiftning': 599.0,
#   'Vibrator udskiftning': 599.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 7 Plus': {'Skærm udskiftning': 449.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 399.0,
#   'Bundhøjtaler udskiftning': 399.0,
#   'Ladestik udskiftning': 499.0,
#   'Mikrofon udskiftning': 499.0,
#   'Volume/Lydløs Funktion udskiftning': 649.0,
#   'Tænd/Sluk funktion (Powerknap) udskiftning': 649.0,
#   'Front kamera udskiftning': 499.0,
#   'Bagkamera udskiftning': 749.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 7': {'Skærm udskiftning': 449.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 399.0,
#   'Bundhøjtaler udskiftning': 399.0,
#   'Mikrofon udskiftning': 449.0,
#   'Volume/Lydløs Funktion udskiftning': 649.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 649.0,
#   'Ladestik udskiftning': 449.0,
#   'Front kamera udskiftning': 399.0,
#   'Bagkamera udskiftning': 499.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6S Plus': {'Skærm udskiftning': 499.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 349.0,
#   'Bundhøjtaler udskiftning': 349.0,
#   'Mikrofon udskiftning': 349.0,
#   'Volume/Lydløs funktion udskiftning': 449.0,
#   'Jackstik udskiftning': 349.0,
#   'Home Knap udskiftning': 349.0,
#   'Tænd/Sluk funktion udskiftning': 449.0,
#   'Ladestik udskiftning': 349.0,
#   'Front Kamera udskiftning': 349.0,
#   'Bagkamera udskiftning': 449.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6S': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 349.0,
#   'Mikrofon udskiftning': 349.0,
#   'Jackstik udskiftning': 349.0,
#   'Ørehøjtaler udskiftning': 349.0,
#   'Bundhøjtaler udskiftning': 349.0,
#   'Volume/Lydløs funktion udskiftning': 449.0,
#   'Tænd/Sluk funktion udskiftning': 449.0,
#   'Home Knap udskiftning': 349.0,
#   'Front Kamera udskiftning': 349.0,
#   'Bagkamera udskiftning': 349.0,
#   'Kameralinse udskiftning': 399.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6 Plus': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 349.0,
#   'Bundhøjtaler udskiftning': 349.0,
#   'Mikrofon udskiftning': 349.0,
#   'Volume/Lydløs funktion udskiftning': 449.0,
#   'Jackstik udskiftning': 349.0,
#   'Home Knap udskiftning': 349.0,
#   'Tænd/Sluk funktion udskiftning': 449.0,
#   'Ladestik udskiftning': 349.0,
#   'Front Kamera udskiftning': 349.0,
#   'Bagkamera udskiftning': 349.0,
#   'Kameralinse udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 6': {'Skærm udskiftning': 349.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Volume/Lydløs funktion udskiftning': 399.0,
#   'Tænd/Sluk funktion udskiftning': 399.0,
#   'Home Knap udskiftning': 299.0,
#   'BagKamera udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Kameralinse udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone SE 2020': {'Skærm udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'Udskiftning af Bagglas': 1000.0,
#   'Batteri udskiftning': 499.0,
#   'Ladestik udskiftning': 599.0,
#   'Mikrofon udskiftning': 599.0,
#   'Ørehøjtaler udskiftning': 400.0,
#   'Bundhøjtaler udskiftning': 599.0,
#   'Front kamera udskiftning': 700.0,
#   'Bagkamera udskiftning': 700.0,
#   'Tænd/Sluk Funktion (Power knap) udskiftning': 800.0,
#   'Volume/Lydløs Funktion udskiftning': 800.0,
#   'Vibrator udskiftning': 400.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone SE': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 5S': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 5C': {'Skærm udskiftning': 299.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 5': {'Skærm udskiftning': 299.0,
#   'Skærmbeskyttelse': 150.0,
#   'Batteri udskiftning': 299.0,
#   'Home knap udskiftning': 299.0,
#   'Front Kamera udskiftning': 299.0,
#   'Bagkamera udskiftning': 299.0,
#   'Mikrofon udskiftning': 299.0,
#   'Ladestik udskiftning': 299.0,
#   'Jackstik udskiftning': 299.0,
#   'Tænd/sluk funktion udskiftning': 299.0,
#   'Lydløs funktion udskiftning': 299.0,
#   'Ørehøjtaler udskiftning': 299.0,
#   'Bundhøjtaler udskiftning': 299.0,
#   'Vibrator udskiftning': 299.0,
#   'Diagnose': 0.0},
#  'Apple iPhones iPhone 4/4S': {'Skærm udskiftning': 399.0,
#   'Skærmbeskyttelse': 100.0,
#   'Batteri udskiftning': 199.0,
#   'Home knap udskiftning': 250.0,
#   'Andre knapper udskiftning': 250.0,
#   'Mikrofon udskiftning': 225.0,
#   'Front Kamera udskiftning': 200.0,
#   'Bagkamera udskiftning': 250.0,
#   'Ladestik udskiftning': 225.0,
#   'Vibrator udskiftning': 200.0,
#   'Jackstik udskiftning': 250.0,
#   'Antenne udskiftning': 220.0,
#   'Ramme udskiftning': 350.0,
#   'WIFI-antenne udskiftning': 220.0,
#   'Ørehøjtaler udskiftning': 200.0,
#   'Bundhøjtaler udskiftning': 200.0,
#   'Diagnose': 0.0},
#  'Apple iPads IPad 2': {'Glas udskiftning': 299.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 499.0,
#   'Batteri udskiftning': 549.0,
#   'Jackstik udskiftning': 499.0,
#   '3G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 499.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Home knap udskiftning': 499.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad 3': {'Glas udskiftning': 349.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 599.0,
#   'Jackstik udskiftning': 499.0,
#   '3G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 499.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Batteri udskiftning': 649.0,
#   'Home knap udskiftning': 499.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad 4': {'Glas udskiftning': 349.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 599.0,
#   'Batteri udskiftning': 649.0,
#   'Jackstik udskiftning': 499.0,
#   '3G/4G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 499.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Home knap udskiftning': 499.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Air': {'Glas udskiftning': 399.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 799.0,
#   'Jackstik udskiftning': 649.0,
#   '3G/4G-antenne udskiftning': 649.0,
#   'WIFI-antenne udskiftning': 649.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 649.0,
#   'Volume/lydløs/power-knap udskiftning': 649.0,
#   'Batteri udskiftning': 649.0,
#   'Home knap udskiftning': 649.0,
#   'Bluetooth-antenne udskiftning': 649.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Air 2': {'Skærm udskiftning': 1249.0,
#   'Skærmbeskyttelse': 200.0,
#   'Batteri udskiftning': 899.0,
#   'Jackstik udskiftning': 699.0,
#   '3G/4G-antenne udskiftning': 699.0,
#   'WIFI-antenne udskiftning': 699.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 699.0,
#   'Volume/lydløs/power-knap udskiftning': 699.0,
#   'Home knap udskiftning': 699.0,
#   'Bluetooth-antenne udskiftning': 699.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Air 2019': {'Skærm Udskiftning': 1799.0},
#  'Apple iPads iPad 9,7 2017': {'Glas udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 999.0,
#   'Jackstik udskiftning': 799.0,
#   '3G/4G-antenne udskiftning': 799.0,
#   'WIFI-antenne udskiftning': 799.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 799.0,
#   'Volume/lydløs/power-knap udskiftning': 799.0,
#   'Batteri udskiftning': 799.0,
#   'Home knap udskiftning': 799.0,
#   'Bluetooth-antenne udskiftning': 799.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad 9,7 2018': {'Glas udskiftning': 699.0,
#   'LCD udskiftning': 999.0,
#   'Batteri udskiftning': 599.0,
#   'Ladestik udskiftning': 999.0},
#  'Apple iPads iPad Mini 1-2': {'Glas udskiftning': 499.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 699.0,
#   'Batteri udskiftning': 699.0,
#   'Jackstik udskiftning': 499.0,
#   '3G/4G-Antenne udskiftning': 499.0,
#   'WIFI-Antenne udskiftning': 499.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 499.0,
#   'Volume/lydløs/power-knap udskiftning': 499.0,
#   'Home knap udskiftning': 699.0,
#   'Bluetooth-antenne udskiftning': 499.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Mini 3': {'Glas udskiftning': 599.0,
#   'Skærmbeskyttelse': 200.0,
#   'LCD udskiftning': 699.0,
#   'Batteri udskiftning': 699.0,
#   'Jackstik udskiftning': 699.0,
#   '3G/4G-Antenne udskiftning': 699.0,
#   'WIFI-Antenne udskiftning': 699.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 699.0,
#   'Volume/lydløs/power-knap udskiftning': 699.0,
#   'Home knap udskiftning': 699.0,
#   'Bluetooth-antenne udskiftning': 699.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Mini 4': {'Skærm udskiftning': 1399.0,
#   'Skærmbeskyttelse': 200.0,
#   'Bagcover udskiftning': 1499.0,
#   'Jackstik udskiftning': 749.0,
#   '3G/4G-Antenne udskiftning': 749.0,
#   'WIFI-Antenne udskiftning': 749.0,
#   'Ladestik udskiftning': 999.0,
#   'Højtaler udskiftning': 749.0,
#   'Volume/lydløs/power-knap udskiftning': 749.0,
#   'Batteri udskiftning': 749.0,
#   'Home knap udskiftning': 749.0,
#   'Bluetooth-antenne udskiftning': 749.0,
#   'Diagnose': 0.0},
#  'Apple iPads iPad Mini 2019': {'Skærm Udskiftning': 1499.0},
#  'Apple iPads iPad PRO': {},
#  'Apple iPads iPad 10,2 2019': {'Skærm Udskiftning': 899.0},
#  'Apple Mac Macbook Pro': {},
#  'Apple Mac Macbook Pro Retina': {},
#  'Apple Mac MacBook Air 11"': {},
#  'Apple Mac MacBook Air 13"': {},
#  'Apple Mac iMac': {},
#  'Apple Mac iMac Retina/4K/5K': {},
#  'Apple Mac Macbook Pro (Uden Touch Bar)': {},
#  'Apple Mac Macbook Pro (Med Touch Bar)': {},
#  'Apple Mac Macbook 12"': {},
#  'Huawei Huawei P30 Pro': {'Udskiftning af skærm': 2800.0},
#  'Huawei Huawei P30': {'Udskiftning af skærm': 1299.0},
#  'Huawei Huawei P30 Lite': {'Udskiftning af skærm': 999.0},
#  'Huawei Huawei Mate 20 Pro': {'Udskiftning af skærm': 3499.0},
#  'Huawei Huawei P20 Pro': {'Glas/LCD - Udskiftning': 2300.0,
#   'Bagside - Udskiftning': 699.0,
#   'Batteri - Udskiftning': nan},
#  'Huawei Huawei Mate 20 Lite': {'Udskiftning af skærm': 1500.0},
#  'Huawei Huawei P20 Lite': {'Glas/LCD - Udskiftning': 799.0,
#   'Bagside - Udskiftning': 599.0,
#   'Batteri - Udskiftning': 499.0},
#  'Huawei Huawei P20': {'Glas/LCD - Udskiftning': 899.0,
#   'Bagside - Udskiftning': 599.0},
#  'Huawei Huawei Mate 10 Pro': {'Glas/LCD - Udskiftning': 2499.0},
#  'Huawei Huawei Mate 9 Pro': {'Glas/LCD - Udskiftning': 3000.0},
#  'Huawei Huawei P10 Plus': {'Glas/LCD - Udskiftning': 1400.0,
#   'Bagside - Udskiftning': 1000.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P9 Plus': {'Glas/LCD - Udskiftning': 1700.0,
#   'Bagside - Udskiftning': 700.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P10 Lite': {'Glas/LCD - Udskiftning': 799.0,
#   'Bagside - Udskiftning': 500.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P10': {'Glas/LCD - Udskiftning': 949.0,
#   'Bagside - Udskiftning': 700.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei Mate 10 Lite': {'Glas/LCD - Udskiftning': 799.0},
#  'Huawei Huawei Mate 10': {'Glas/LCD - Udskiftning': 1099.0},
#  'Huawei Huawei P9 Lite': {'Glas/LCD - Udskiftning': 749.0,
#   'Bagside - Udskiftning': 500.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P9': {'Glas/LCD - Udskiftning': 899.0,
#   'Bagside - Udskiftning': 600.0,
#   'Batteri - Udskiftning': 600.0},
#  'Huawei Huawei Honor 9 Lite': {'Glas/LCD - Udskiftning': 849.0},
#  'Huawei Huawei Honor 9': {'Glas/LCD - Udskiftning': 1699.0},
#  'Huawei Huawei P8 Lite': {'Glas/LCD - Udskiftning': 750.0,
#   'Bagside - Udskiftning': 500.0,
#   'Batteri - Udskiftning': 500.0},
#  'Huawei Huawei P8': {'Glas/LCD - Udskiftning': 750.0,
#   'Bagside Udskiftning': 500.0,
#   'Batteri Udskiftning': 500.0},
#  'Huawei Huawei P Smart 2019': {'Udskiftning af skærm': 899.0},
#  'Huawei Huawei P-Smart': {'Udskiftning af skærm': 799.0},
#  'Huawei Huawei Y6 2019': {'Udskiftning af skærm': 1000.0},
#  'Huawei Huawei Y5 2019': {'Udskiftning af skærm': 1100.0},
#  'Huawei Huawei P Smart Z': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S8': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S6': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S10 Plus': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S10 Komplet skærm Udskiftning': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S10E Komplet skærm Udskiftning': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S9 PLUS': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S9': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S8 PLUS': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S7 Edge': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S7': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S6 Edge +': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S6 Edge': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5 Mini': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5 Neo': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S5 Active': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4 +': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4 Mini': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S4 Active': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S3 Mini': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S +': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S Advance': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy S Duos': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 10': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 9': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 8': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note 2/4G LTE': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Note Edge': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover 2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover 3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy XCover 4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A80': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A70': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A50': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A40': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A20E': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A10': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A9 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A8 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A7': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A6 (PLUS 2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A6 (2018)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A5 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A5 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A3 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A3 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy A3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Alpha': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace Plus': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace Style': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace 2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace 3': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ace 4': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J7 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J7 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J5 (2017)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J5 (2016)': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J5': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy W': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy R': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Omnia': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Mega': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy J1': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Express 2': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Express': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Grand 2 Duos': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Core Prime': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Core Plus': {'Udskiftning af skærm': 1300.0},
#  'Samsung Galaxy Ativ S': {'Udskiftning af skærm': 1300.0},
#  'Sony Xperia Z5 Premium': {'Komplet Skærm Udskiftning': 2000.0},
#  'Sony Xperia Z5 Compact': {'Glas/LCD': 1199.0, 'BAGSIDE': 500.0},
#  'Sony Xperia Z5': {'GLAS/LCD': 1500.0, 'BAGSIDE': 500.0},
#  'Sony Xperia Z4 (Z3+)': {'GLAS/LCD': 1499.0, 'Bagside': 500.0},
#  'Sony Xperia Z3 Compact': {'Glas/LCD': 999.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z3': {'Glas/LCD': 1199.0, 'Bagside': 399.0, 'Diagnose': 0.0},
#  'Sony Xperia Z2': {'Glas/LCD': 999.0, 'Bagside': 399.0, 'Diagnose': 0.0},
#  'Sony Xperia Z1 Compact': {'Glas/LCD': 800.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z1': {'Komplet LCD + glas': 849.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z': {'Komplet LCD + glas': 849.0,
#   'Bagside': 399.0,
#   'Diagnose': 0.0},
#  'Sony Xperia Z Ultra': {'Komplet Skærm Udskiftning': 2200.0},
#  'Sony Diverse Modeller': {'Xperia Go Komplet Skærm Udskiftning': 1000.0,
#   'Xperia E4 Komplet Skærm Udskiftning': 800.0,
#   'Xperia U Glas Udskiftning': 600.0},
#  'Sony X-Serien': {'Xperia X Performance Komplet Skærm Udskiftning': 1800.0,
#   'Xperia X Performance Dual Komplet Skærm Udskiftning': 1800.0,
#   'Xperia X Komplet Skærm Udskiftning': 1500.0,
#   'Xperia XA Komplet Skærm Udskiftning': 1000.0,
#   'Xperia XA1 Komplet Skærm Udskiftning': 1100.0,
#   'Xperia XA Dual Komplet Skærm Udskiftning': 1000.0},
#  'Sony M-Serie': {'Xperia M Glas Udskiftning': 700.0,
#   'Xperia M2 Glas Udskiftning': 800.0,
#   'Xperia M2 Aqua Komplet Skærm Udskiftning': 1000.0,
#   'Xperia M4 Aqua Komplet Skærm Udskiftning': 1000.0,
#   'Xperia M5 Komplet Skærm Udskiftning': 1200.0},
#  'One Plus OnePlus 7 Pro': {'Skærm Udskiftning': 3500.0},
#  'One Plus OnePlus 7': {'Skærm Udskiftning': 2500.0},
#  'One Plus OnePlus 6T': {'Skærm Udskiftning': 2000.0, 'Bagside': 700.0},
#  'One Plus OnePlus 6': {'Skærm Udskiftning': 1799.0, 'Bagside': 699.0},
#  'One Plus OnePlus 5T': {'Skærm Udskiftning': 1399.0,
#   'Batteri Udskiftning': 700.0},
#  'One Plus OnePlus 5': {'Skærm Udskiftning': 1199.0,
#   'Batteri Udskiftning': 600.0},
#  'One Plus OnePlus 3T': {'Skærm Udskiftning': 1249.0,
#   'Batteri Udskiftning': 600.0},
#  'One Plus OnePlus 3': {'GLAS/LCD': 1249.0},
#  'One Plus OnePlus 2': {'GLAS/LCD': 849.0, 'Diagnose': 0.0},
#  'One Plus OnePlus One': {'GLAS/LCD': 849.0,
#   'Ladestik': 600.0,
#   'Diagnose': 0.0},
#  'One Plus OnePlus X': {'GLAS/LCD': 1199.0},
#  'LG LG G6': {'Glas/LCD Udskiftning': 1500.0},
#  'LG LG G5': {'Komplet Skærm Udskiftning': 2000.0},
#  'LG LG G4S': {'Komplet Skærm Udskiftning': 1000.0},
#  'LG LG G4': {'GLAS/LCD': 1100.0, 'Diagnose': 0.0},
#  'LG LG G3S': {'Glas Udskiftning': 800.0},
#  'LG LG G3': {'GLAS/LCD': 1000.0, 'Diagnose': 0.0},
#  'LG LG G2': {'Skærm/LCD': 950.0, 'Diagnose': 0.0},
#  'LG LG G2 MINI': {'GLAS': 700.0, 'LCD': 900.0, 'Diagnose': 0.0},
#  'LG LG Nexus 5X': {'Komplet Skærm Udskiftning': 1200.0},
#  'LG LG (GOOGLE) NEXUS 5': {'Komplet LCD + glas': 1200.0, 'Diagnose': 0.0},
#  'LG LG (GOOGLE) NEXUS 4': {'Skærm/LCD': 1100.0, 'Diagnose': 0.0},
#  'LG LG G FLEX 2': {'GLAS/LCD': 1800.0, 'Diagnose': 0.0},
#  'LG LG G Flex': {'Glas/LCD': 1700.0, 'Diagnose': 0.0},
#  'LG LG OPTIMUS G': {'Skærm/LCD': 950.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 1520': {'Glas/LCD': 1200.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 1320': {'Glas/LCD': 1500.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 1020': {'Glas/LCD': 1000.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 935': {'Glas/LCD': 1800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 930': {'Glas/LCD': 1800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 920': {'Glas/LCD': 1200.0, 'Glas': 600.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 900': {'Komplet LCD + glas': 1200.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 830': {'Glas/LCD': 1600.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 820': {'LCD': 900.0,
#   'Glas': 700.0,
#   'Komplet LCD + glas': 1200.0,
#   'Diagnose': 0.0},
#  'Nokia Nokia Lumia 800': {'Komplet LCD + glas': 800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 735': {'Glas/LCD': 800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 730': {'Glas/ LCD': 800.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 720': {'Glas/LCD': 1200.0, 'Diagnose': 0.0},
#  'Nokia Nokia Lumia 710': {'Glas': 800.0, 'LCD': 800.0, 'Diagnose': 0.0}}

# %%
reparations_names = []
for item in repair_cost_dict.items():
    phone_name = item[0]
    reparations = item[1]
    for reparation in reparations:
        reparations_names.append(reparation)

# %%
def convert_reparation_name(reparation_name):
    reparation_name_transformed = reparation_name
    if re.match("(.*Komplet (S|s)kærm.*)|(.*Glas/ LCD.*)|(.*Glas/LCD.*)|(.*LCD.*)|(.*(S|s)kærm.*)", reparation_name) is not None:
        reparation_name_transformed = "screen"
    if re.match("(.*3G.*)|(.*Antenne.*)", reparation_name) is not None:
        reparation_name_transformed = "3G_4G"
    if re.match(".*Batteri.*", reparation_name) is not None:
        reparation_name_transformed = "battery"
    if re.match("(.*BAGSIDE.*)|(.*Bagside.*)|(.*Bagcover.*)|(.*Bagglas.*)", reparation_name) is not None:
        reparation_name_transformed = "back_frame"
    if re.match("(.*GLAS.*)|(.*Glas.*)", reparation_name) is not None:
        reparation_name_transformed = "glass"
    if re.match(".*Bluetooth.*", reparation_name) is not None:
        reparation_name_transformed = "bluetooth"
    if re.match(".*WIFI.*", reparation_name) is not None:
        reparation_name_transformed = "wifi"
    if re.match("(.*BagKamera.*)|(.*Bagkamera.*)", reparation_name) is not None:
        reparation_name_transformed = "back_camera"
    if re.match(".*Front (K|k)amera.*", reparation_name) is not None:
        reparation_name_transformed = "back_camera"
    if re.match(".*Diagnose.*", reparation_name) is not None:
        reparation_name_transformed = "diagnose"
    if re.match(".*Ladestik.*", reparation_name) is not None:
        reparation_name_transformed = "charging_socket"
    if re.match("(.*Vibrator.*)", reparation_name) is not None:
        reparation_name_transformed = "vibrator"
    if re.match("(.*Tænd/(S|s)luk.*)", reparation_name) is not None:
        reparation_name_transformed = "power_cable"
    if re.match("(.*Volume/(L|l)ydløs.*)|(.*Lydløs.*)", reparation_name) is not None:
        reparation_name_transformed = "volume_button"
    if re.match("(.*Bundhøjtaler.*)|(.*Højtaler.*)|(.*Ørehøjtaler.*)", reparation_name) is not None:
        reparation_name_transformed = "speaker"
    if re.match("(.*Ramme.*)", reparation_name) is not None:
        reparation_name_transformed = "full_frame"
    if re.match("(.*Mikrofon.*)", reparation_name) is not None:
        reparation_name_transformed = "microphone"
    if re.match("(.*Kameralinse.*)", reparation_name) is not None:
        reparation_name_transformed = "camera_lens"
    if re.match("(.*audio.*)|(.*Jackstik.*)", reparation_name) is not None:
        reparation_name_transformed = "audio_port"
    if re.match("(.*(H|h)ome (K|k)nap.*)", reparation_name) is not None:
        reparation_name_transformed = "home_button"
    if re.match("(.*Andre knapper.*)", reparation_name) is not None:
        reparation_name_transformed = "other_button"      
    return reparation_name_transformed

# %%
for phone_name, reparations in repair_cost_dict.items():
    for reparation_name, reparation_cost in reparations.copy().items():
        reparations[convert_reparation_name(reparation_name)] = reparations.pop(reparation_name)

# %%
repair_cost_dict
# Out:
# {'Apple iPhones IPhone 11 Pro Max': {'screen': 200.0,
#   'back_frame': 1500.0,
#   'battery': nan},
#  'Apple iPhones iPhone 11 Pro': {'screen': 200.0,
#   'back_frame': 1500.0,
#   'battery': nan},
#  'Apple iPhones iPhone 11': {'screen': 200.0,
#   'back_frame': 1500.0,
#   'battery': nan},
#  'Apple iPhones iPhone XS Max': {'screen': 200.0,
#   'back_frame': 1000.0,
#   'battery': 999.0,
#   'charging_socket': 999.0,
#   'microphone': 999.0,
#   'speaker': 799.0,
#   'back_camera': 1200.0,
#   'camera_lens': 799.0,
#   'power_cable': 999.0,
#   'volume_button': 999.0,
#   'vibrator': 799.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone XS': {'screen': 200.0,
#   'back_frame': 900.0,
#   'battery': 799.0,
#   'charging_socket': 999.0,
#   'microphone': 999.0,
#   'speaker': 799.0,
#   'back_camera': 1200.0,
#   'camera_lens': 799.0,
#   'power_cable': 999.0,
#   'volume_button': 999.0,
#   'vibrator': 799.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone XR': {'screen': 200.0,
#   'back_frame': 900.0,
#   'battery': 799.0,
#   'charging_socket': 999.0,
#   'microphone': 999.0,
#   'speaker': 799.0,
#   'back_camera': 999.0,
#   'camera_lens': 799.0,
#   'power_cable': 999.0,
#   'volume_button': 999.0,
#   'vibrator': 799.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone X': {'screen': 200.0,
#   'back_frame': 900.0,
#   'battery': 799.0,
#   'charging_socket': 999.0,
#   'microphone': 999.0,
#   'speaker': 799.0,
#   'back_camera': 1200.0,
#   'power_cable': 999.0,
#   'volume_button': 999.0,
#   'vibrator': 799.0,
#   'camera_lens': 799.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 8 Plus': {'screen': 200.0,
#   'back_frame': 800.0,
#   'battery': 399.0,
#   'charging_socket': 699.0,
#   'microphone': 699.0,
#   'speaker': 699.0,
#   'back_camera': 699.0,
#   'power_cable': 699.0,
#   'volume_button': 699.0,
#   'vibrator': 699.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 8': {'screen': 200.0,
#   'back_frame': 800.0,
#   'battery': 399.0,
#   'charging_socket': 599.0,
#   'microphone': 599.0,
#   'speaker': 599.0,
#   'back_camera': 599.0,
#   'power_cable': 599.0,
#   'volume_button': 599.0,
#   'vibrator': 599.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 7 Plus': {'screen': 200.0,
#   'battery': 299.0,
#   'speaker': 399.0,
#   'charging_socket': 499.0,
#   'microphone': 499.0,
#   'volume_button': 649.0,
#   'power_cable': 649.0,
#   'back_camera': 749.0,
#   'camera_lens': 399.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 7': {'screen': 200.0,
#   'battery': 299.0,
#   'speaker': 399.0,
#   'microphone': 449.0,
#   'volume_button': 649.0,
#   'power_cable': 649.0,
#   'charging_socket': 449.0,
#   'back_camera': 499.0,
#   'camera_lens': 399.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 6S Plus': {'screen': 200.0,
#   'battery': 299.0,
#   'speaker': 349.0,
#   'microphone': 349.0,
#   'volume_button': 449.0,
#   'audio_port': 349.0,
#   'home_button': 349.0,
#   'power_cable': 449.0,
#   'charging_socket': 349.0,
#   'back_camera': 449.0,
#   'camera_lens': 399.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 6S': {'screen': 200.0,
#   'battery': 299.0,
#   'charging_socket': 349.0,
#   'microphone': 349.0,
#   'audio_port': 349.0,
#   'speaker': 349.0,
#   'volume_button': 449.0,
#   'power_cable': 449.0,
#   'home_button': 349.0,
#   'back_camera': 349.0,
#   'camera_lens': 399.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 6 Plus': {'screen': 200.0,
#   'battery': 299.0,
#   'speaker': 349.0,
#   'microphone': 349.0,
#   'volume_button': 449.0,
#   'audio_port': 349.0,
#   'home_button': 349.0,
#   'power_cable': 449.0,
#   'charging_socket': 349.0,
#   'back_camera': 349.0,
#   'camera_lens': 299.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 6': {'screen': 200.0,
#   'battery': 299.0,
#   'charging_socket': 299.0,
#   'microphone': 299.0,
#   'audio_port': 299.0,
#   'speaker': 299.0,
#   'volume_button': 399.0,
#   'power_cable': 399.0,
#   'home_button': 299.0,
#   'back_camera': 299.0,
#   'camera_lens': 299.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone SE 2020': {'screen': 200.0,
#   'back_frame': 1000.0,
#   'battery': 499.0,
#   'charging_socket': 599.0,
#   'microphone': 599.0,
#   'speaker': 599.0,
#   'back_camera': 700.0,
#   'power_cable': 800.0,
#   'volume_button': 800.0,
#   'vibrator': 400.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone SE': {'screen': 150.0,
#   'battery': 299.0,
#   'microphone': 299.0,
#   'home_button': 299.0,
#   'back_camera': 299.0,
#   'power_cable': 299.0,
#   'charging_socket': 299.0,
#   'volume_button': 299.0,
#   'speaker': 299.0,
#   'audio_port': 299.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 5S': {'screen': 150.0,
#   'battery': 299.0,
#   'charging_socket': 299.0,
#   'microphone': 299.0,
#   'home_button': 299.0,
#   'back_camera': 299.0,
#   'power_cable': 299.0,
#   'volume_button': 299.0,
#   'speaker': 299.0,
#   'audio_port': 299.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 5C': {'screen': 150.0,
#   'battery': 299.0,
#   'charging_socket': 299.0,
#   'speaker': 299.0,
#   'audio_port': 299.0,
#   'microphone': 299.0,
#   'home_button': 299.0,
#   'back_camera': 299.0,
#   'power_cable': 299.0,
#   'volume_button': 299.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 5': {'screen': 150.0,
#   'battery': 299.0,
#   'home_button': 299.0,
#   'back_camera': 299.0,
#   'microphone': 299.0,
#   'charging_socket': 299.0,
#   'audio_port': 299.0,
#   'power_cable': 299.0,
#   'volume_button': 299.0,
#   'speaker': 299.0,
#   'vibrator': 299.0,
#   'diagnose': 0.0},
#  'Apple iPhones iPhone 4/4S': {'screen': 100.0,
#   'battery': 199.0,
#   'home_button': 250.0,
#   'other_button': 250.0,
#   'microphone': 225.0,
#   'back_camera': 250.0,
#   'charging_socket': 225.0,
#   'vibrator': 200.0,
#   'audio_port': 250.0,
#   '3G_4G': 220.0,
#   'full_frame': 350.0,
#   'wifi': 220.0,
#   'speaker': 200.0,
#   'diagnose': 0.0},
#  'Apple iPads IPad 2': {'glass': 299.0,
#   'screen': 499.0,
#   'battery': 549.0,
#   'audio_port': 499.0,
#   '3G_4G': 499.0,
#   'wifi': 499.0,
#   'charging_socket': 499.0,
#   'speaker': 499.0,
#   'volume_button': 499.0,
#   'home_button': 499.0,
#   'bluetooth': 499.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad 3': {'glass': 349.0,
#   'screen': 599.0,
#   'audio_port': 499.0,
#   '3G_4G': 499.0,
#   'wifi': 499.0,
#   'charging_socket': 499.0,
#   'speaker': 499.0,
#   'volume_button': 499.0,
#   'battery': 649.0,
#   'home_button': 499.0,
#   'bluetooth': 499.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad 4': {'glass': 349.0,
#   'screen': 599.0,
#   'battery': 649.0,
#   'audio_port': 499.0,
#   '3G_4G': 499.0,
#   'wifi': 499.0,
#   'charging_socket': 499.0,
#   'speaker': 499.0,
#   'volume_button': 499.0,
#   'home_button': 499.0,
#   'bluetooth': 499.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad Air': {'glass': 399.0,
#   'screen': 799.0,
#   'audio_port': 649.0,
#   '3G_4G': 649.0,
#   'wifi': 649.0,
#   'charging_socket': 999.0,
#   'speaker': 649.0,
#   'volume_button': 649.0,
#   'battery': 649.0,
#   'home_button': 649.0,
#   'bluetooth': 649.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad Air 2': {'screen': 200.0,
#   'battery': 899.0,
#   'audio_port': 699.0,
#   '3G_4G': 699.0,
#   'wifi': 699.0,
#   'charging_socket': 999.0,
#   'speaker': 699.0,
#   'volume_button': 699.0,
#   'home_button': 699.0,
#   'bluetooth': 699.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad Air 2019': {'screen': 1799.0},
#  'Apple iPads iPad 9,7 2017': {'glass': 599.0,
#   'screen': 999.0,
#   'audio_port': 799.0,
#   '3G_4G': 799.0,
#   'wifi': 799.0,
#   'charging_socket': 999.0,
#   'speaker': 799.0,
#   'volume_button': 799.0,
#   'battery': 799.0,
#   'home_button': 799.0,
#   'bluetooth': 799.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad 9,7 2018': {'glass': 699.0,
#   'screen': 999.0,
#   'battery': 599.0,
#   'charging_socket': 999.0},
#  'Apple iPads iPad Mini 1-2': {'glass': 499.0,
#   'screen': 699.0,
#   'battery': 699.0,
#   'audio_port': 499.0,
#   '3G_4G': 499.0,
#   'wifi': 499.0,
#   'charging_socket': 999.0,
#   'speaker': 499.0,
#   'volume_button': 499.0,
#   'home_button': 699.0,
#   'bluetooth': 499.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad Mini 3': {'glass': 599.0,
#   'screen': 699.0,
#   'battery': 699.0,
#   'audio_port': 699.0,
#   '3G_4G': 699.0,
#   'wifi': 699.0,
#   'charging_socket': 999.0,
#   'speaker': 699.0,
#   'volume_button': 699.0,
#   'home_button': 699.0,
#   'bluetooth': 699.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad Mini 4': {'screen': 200.0,
#   'back_frame': 1499.0,
#   'audio_port': 749.0,
#   '3G_4G': 749.0,
#   'wifi': 749.0,
#   'charging_socket': 999.0,
#   'speaker': 749.0,
#   'volume_button': 749.0,
#   'battery': 749.0,
#   'home_button': 749.0,
#   'bluetooth': 749.0,
#   'diagnose': 0.0},
#  'Apple iPads iPad Mini 2019': {'screen': 1499.0},
#  'Apple iPads iPad PRO': {},
#  'Apple iPads iPad 10,2 2019': {'screen': 899.0},
#  'Apple Mac Macbook Pro': {},
#  'Apple Mac Macbook Pro Retina': {},
#  'Apple Mac MacBook Air 11"': {},
#  'Apple Mac MacBook Air 13"': {},
#  'Apple Mac iMac': {},
#  'Apple Mac iMac Retina/4K/5K': {},
#  'Apple Mac Macbook Pro (Uden Touch Bar)': {},
#  'Apple Mac Macbook Pro (Med Touch Bar)': {},
#  'Apple Mac Macbook 12"': {},
#  'Huawei Huawei P30 Pro': {'screen': 2800.0},
#  'Huawei Huawei P30': {'screen': 1299.0},
#  'Huawei Huawei P30 Lite': {'screen': 999.0},
#  'Huawei Huawei Mate 20 Pro': {'screen': 3499.0},
#  'Huawei Huawei P20 Pro': {'glass': 2300.0,
#   'back_frame': 699.0,
#   'battery': nan},
#  'Huawei Huawei Mate 20 Lite': {'screen': 1500.0},
#  'Huawei Huawei P20 Lite': {'glass': 799.0,
#   'back_frame': 599.0,
#   'battery': 499.0},
#  'Huawei Huawei P20': {'glass': 899.0, 'back_frame': 599.0},
#  'Huawei Huawei Mate 10 Pro': {'glass': 2499.0},
#  'Huawei Huawei Mate 9 Pro': {'glass': 3000.0},
#  'Huawei Huawei P10 Plus': {'glass': 1400.0,
#   'back_frame': 1000.0,
#   'battery': 500.0},
#  'Huawei Huawei P9 Plus': {'glass': 1700.0,
#   'back_frame': 700.0,
#   'battery': 500.0},
#  'Huawei Huawei P10 Lite': {'glass': 799.0,
#   'back_frame': 500.0,
#   'battery': 500.0},
#  'Huawei Huawei P10': {'glass': 949.0, 'back_frame': 700.0, 'battery': 500.0},
#  'Huawei Huawei Mate 10 Lite': {'glass': 799.0},
#  'Huawei Huawei Mate 10': {'glass': 1099.0},
#  'Huawei Huawei P9 Lite': {'glass': 749.0,
#   'back_frame': 500.0,
#   'battery': 500.0},
#  'Huawei Huawei P9': {'glass': 899.0, 'back_frame': 600.0, 'battery': 600.0},
#  'Huawei Huawei Honor 9 Lite': {'glass': 849.0},
#  'Huawei Huawei Honor 9': {'glass': 1699.0},
#  'Huawei Huawei P8 Lite': {'glass': 750.0,
#   'back_frame': 500.0,
#   'battery': 500.0},
#  'Huawei Huawei P8': {'glass': 750.0, 'back_frame': 500.0, 'battery': 500.0},
#  'Huawei Huawei P Smart 2019': {'screen': 899.0},
#  'Huawei Huawei P-Smart': {'screen': 799.0},
#  'Huawei Huawei Y6 2019': {'screen': 1000.0},
#  'Huawei Huawei Y5 2019': {'screen': 1100.0},
#  'Huawei Huawei P Smart Z': {'screen': 1300.0},
#  'Samsung Galaxy S8': {'screen': 1300.0},
#  'Samsung Galaxy S6': {'screen': 1300.0},
#  'Samsung Galaxy S10 Plus': {'screen': 1300.0},
#  'Samsung Galaxy S10 Komplet skærm Udskiftning': {'screen': 1300.0},
#  'Samsung Galaxy S10E Komplet skærm Udskiftning': {'screen': 1300.0},
#  'Samsung Galaxy S9 PLUS': {'screen': 1300.0},
#  'Samsung Galaxy S9': {'screen': 1300.0},
#  'Samsung Galaxy S8 PLUS': {'screen': 1300.0},
#  'Samsung Galaxy S7 Edge': {'screen': 1300.0},
#  'Samsung Galaxy S7': {'screen': 1300.0},
#  'Samsung Galaxy S6 Edge +': {'screen': 1300.0},
#  'Samsung Galaxy S6 Edge': {'screen': 1300.0},
#  'Samsung Galaxy S5': {'screen': 1300.0},
#  'Samsung Galaxy S5 Mini': {'screen': 1300.0},
#  'Samsung Galaxy S5 Neo': {'screen': 1300.0},
#  'Samsung Galaxy S5 Active': {'screen': 1300.0},
#  'Samsung Galaxy S4 +': {'screen': 1300.0},
#  'Samsung Galaxy S4': {'screen': 1300.0},
#  'Samsung Galaxy S4 Mini': {'screen': 1300.0},
#  'Samsung Galaxy S4 Active': {'screen': 1300.0},
#  'Samsung Galaxy S3': {'screen': 1300.0},
#  'Samsung Galaxy S3 Mini': {'screen': 1300.0},
#  'Samsung Galaxy S2': {'screen': 1300.0},
#  'Samsung Galaxy S +': {'screen': 1300.0},
#  'Samsung Galaxy S': {'screen': 1300.0},
#  'Samsung Galaxy S Advance': {'screen': 1300.0},
#  'Samsung Galaxy S Duos': {'screen': 1300.0},
#  'Samsung Galaxy Note 10': {'screen': 1300.0},
#  'Samsung Galaxy Note 9': {'screen': 1300.0},
#  'Samsung Galaxy Note 8': {'screen': 1300.0},
#  'Samsung Galaxy Note 5': {'screen': 1300.0},
#  'Samsung Galaxy Note 4': {'screen': 1300.0},
#  'Samsung Galaxy Note 3': {'screen': 1300.0},
#  'Samsung Galaxy Note 2/4G LTE': {'screen': 1300.0},
#  'Samsung Galaxy Note': {'screen': 1300.0},
#  'Samsung Galaxy Note Edge': {'screen': 1300.0},
#  'Samsung Galaxy XCover': {'screen': 1300.0},
#  'Samsung Galaxy XCover 2': {'screen': 1300.0},
#  'Samsung Galaxy XCover 3': {'screen': 1300.0},
#  'Samsung Galaxy XCover 4': {'screen': 1300.0},
#  'Samsung Galaxy A80': {'screen': 1300.0},
#  'Samsung Galaxy A70': {'screen': 1300.0},
#  'Samsung Galaxy A50': {'screen': 1300.0},
#  'Samsung Galaxy A40': {'screen': 1300.0},
#  'Samsung Galaxy A20E': {'screen': 1300.0},
#  'Samsung Galaxy A10': {'screen': 1300.0},
#  'Samsung Galaxy A9 (2018)': {'screen': 1300.0},
#  'Samsung Galaxy A8 (2018)': {'screen': 1300.0},
#  'Samsung Galaxy A7 (2018)': {'screen': 1300.0},
#  'Samsung Galaxy A7 (2017)': {'screen': 1300.0},
#  'Samsung Galaxy A7 (2016)': {'screen': 1300.0},
#  'Samsung Galaxy A7': {'screen': 1300.0},
#  'Samsung Galaxy A6 (PLUS 2018)': {'screen': 1300.0},
#  'Samsung Galaxy A6 (2018)': {'screen': 1300.0},
#  'Samsung Galaxy A5 (2017)': {'screen': 1300.0},
#  'Samsung Galaxy A5 (2016)': {'screen': 1300.0},
#  'Samsung Galaxy A5': {'screen': 1300.0},
#  'Samsung Galaxy A3 (2017)': {'screen': 1300.0},
#  'Samsung Galaxy A3 (2016)': {'screen': 1300.0},
#  'Samsung Galaxy A3': {'screen': 1300.0},
#  'Samsung Galaxy Alpha': {'screen': 1300.0},
#  'Samsung Galaxy Ace Plus': {'screen': 1300.0},
#  'Samsung Galaxy Ace Style': {'screen': 1300.0},
#  'Samsung Galaxy Ace 2': {'screen': 1300.0},
#  'Samsung Galaxy Ace 3': {'screen': 1300.0},
#  'Samsung Galaxy Ace 4': {'screen': 1300.0},
#  'Samsung Galaxy J7 (2017)': {'screen': 1300.0},
#  'Samsung Galaxy J7 (2016)': {'screen': 1300.0},
#  'Samsung Galaxy J5 (2017)': {'screen': 1300.0},
#  'Samsung Galaxy J5 (2016)': {'screen': 1300.0},
#  'Samsung Galaxy J5': {'screen': 1300.0},
#  'Samsung Galaxy W': {'screen': 1300.0},
#  'Samsung Galaxy R': {'screen': 1300.0},
#  'Samsung Galaxy Omnia': {'screen': 1300.0},
#  'Samsung Galaxy Mega': {'screen': 1300.0},
#  'Samsung Galaxy J1': {'screen': 1300.0},
#  'Samsung Galaxy Express 2': {'screen': 1300.0},
#  'Samsung Galaxy Express': {'screen': 1300.0},
#  'Samsung Galaxy Grand 2 Duos': {'screen': 1300.0},
#  'Samsung Galaxy Core Prime': {'screen': 1300.0},
#  'Samsung Galaxy Core Plus': {'screen': 1300.0},
#  'Samsung Galaxy Ativ S': {'screen': 1300.0},
#  'Sony Xperia Z5 Premium': {'screen': 2000.0},
#  'Sony Xperia Z5 Compact': {'glass': 1199.0, 'back_frame': 500.0},
#  'Sony Xperia Z5': {'glass': 1500.0, 'back_frame': 500.0},
#  'Sony Xperia Z4 (Z3+)': {'glass': 1499.0, 'back_frame': 500.0},
#  'Sony Xperia Z3 Compact': {'glass': 999.0,
#   'back_frame': 399.0,
#   'diagnose': 0.0},
#  'Sony Xperia Z3': {'glass': 1199.0, 'back_frame': 399.0, 'diagnose': 0.0},
#  'Sony Xperia Z2': {'glass': 999.0, 'back_frame': 399.0, 'diagnose': 0.0},
#  'Sony Xperia Z1 Compact': {'glass': 800.0,
#   'back_frame': 399.0,
#   'diagnose': 0.0},
#  'Sony Xperia Z1': {'screen': 849.0, 'back_frame': 399.0, 'diagnose': 0.0},
#  'Sony Xperia Z': {'screen': 849.0, 'back_frame': 399.0, 'diagnose': 0.0},
#  'Sony Xperia Z Ultra': {'screen': 2200.0},
#  'Sony Diverse Modeller': {'screen': 800.0, 'glass': 600.0},
#  'Sony X-Serien': {'screen': 1000.0},
#  'Sony M-Serie': {'glass': 800.0, 'screen': 1200.0},
#  'One Plus OnePlus 7 Pro': {'screen': 3500.0},
#  'One Plus OnePlus 7': {'screen': 2500.0},
#  'One Plus OnePlus 6T': {'screen': 2000.0, 'back_frame': 700.0},
#  'One Plus OnePlus 6': {'screen': 1799.0, 'back_frame': 699.0},
#  'One Plus OnePlus 5T': {'screen': 1399.0, 'battery': 700.0},
#  'One Plus OnePlus 5': {'screen': 1199.0, 'battery': 600.0},
#  'One Plus OnePlus 3T': {'screen': 1249.0, 'battery': 600.0},
#  'One Plus OnePlus 3': {'glass': 1249.0},
#  'One Plus OnePlus 2': {'glass': 849.0, 'diagnose': 0.0},
#  'One Plus OnePlus One': {'glass': 849.0,
#   'charging_socket': 600.0,
#   'diagnose': 0.0},
#  'One Plus OnePlus X': {'glass': 1199.0},
#  'LG LG G6': {'glass': 1500.0},
#  'LG LG G5': {'screen': 2000.0},
#  'LG LG G4S': {'screen': 1000.0},
#  'LG LG G4': {'glass': 1100.0, 'diagnose': 0.0},
#  'LG LG G3S': {'glass': 800.0},
#  'LG LG G3': {'glass': 1000.0, 'diagnose': 0.0},
#  'LG LG G2': {'screen': 950.0, 'diagnose': 0.0},
#  'LG LG G2 MINI': {'glass': 700.0, 'screen': 900.0, 'diagnose': 0.0},
#  'LG LG Nexus 5X': {'screen': 1200.0},
#  'LG LG (GOOGLE) NEXUS 5': {'screen': 1200.0, 'diagnose': 0.0},
#  'LG LG (GOOGLE) NEXUS 4': {'screen': 1100.0, 'diagnose': 0.0},
#  'LG LG G FLEX 2': {'glass': 1800.0, 'diagnose': 0.0},
#  'LG LG G Flex': {'glass': 1700.0, 'diagnose': 0.0},
#  'LG LG OPTIMUS G': {'screen': 950.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 1520': {'glass': 1200.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 1320': {'glass': 1500.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 1020': {'glass': 1000.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 935': {'glass': 1800.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 930': {'glass': 1800.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 920': {'glass': 600.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 900': {'screen': 1200.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 830': {'glass': 1600.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 820': {'screen': 1200.0, 'glass': 700.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 800': {'screen': 800.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 735': {'glass': 800.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 730': {'glass': 800.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 720': {'glass': 1200.0, 'diagnose': 0.0},
#  'Nokia Nokia Lumia 710': {'glass': 800.0, 'screen': 800.0, 'diagnose': 0.0}}
