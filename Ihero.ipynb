# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
import pprint

# %%
def get_brands_urls(main_url="https://ihero.dk/priser/"):
    html = urlopen(main_url)
    soup = BeautifulSoup(html, "html.parser")
    # we extract the urls corresponding to each of the phones on the page of the brand
    urls = {}
    brand_soups = soup.find_all("a", class_="col m:w1/1 brand-box")
    n=0
    while True:
        try:
            brand = brand_soups[n].find("span", class_="brand-box-title").contents[0].replace("Reparation af", "").strip()
            url = brand_soups[n].get("href")
            
            if brand in ["iPhones", "iPads", "Mac"]:
                brand="Apple" + " " + brand
            elif brand in ["PCer"]:
                brand="PC"
            
            urls[brand] = url
            n+=1

        except:
            break
    return urls

get_brands_urls()
# Out:
# {'Apple iPhones': 'https://ihero.dk/iphone-reparation-2/',
#  'Apple iPads': 'https://ihero.dk/ipad-reparation/',
#  'Apple Mac': 'https://ihero.dk/mac-reparation/',
#  'Huawei': 'https://ihero.dk/huawei/',
#  'Samsung': 'https://ihero.dk/samsung-reparation/',
#  'Sony': 'https://ihero.dk/sony-reparation/',
#  'One Plus': 'https://ihero.dk/one-plus/',
#  'LG': 'https://ihero.dk/lg-reparation/',
#  'Nokia': 'https://ihero.dk/nokia-reparation/',
#  'PC': 'https://ihero.dk/pc-reparation/'}

# %%
def get_series_urls(brand_name, brand_url):
    html = urlopen(brand_url)
    soup = BeautifulSoup(html, "html.parser")
    series_soups = soup.find_all("a", class_="col m:w1/1 brand-box")
    series_urls = {}
    for serie_soup in series_soups:
        print(serie_soup)
        serie_name = serie_soup.find("span", class_="brand-box-title").contents[0]
        url = serie_soup.get("href")
        serie_name = serie_name.replace("-Serien", "").strip()
        series_urls[serie_name] = url
    return series_urls

get_series_urls('Samsung', 'https://ihero.dk/samsung-reparation/')
# Out:
# <a class="col m:w1/1 brand-box" href="https://ihero.dk/samsung-galaxy-s5-2/"> <span class="brand-box-img rocket-lazyload" data-bg="https://ihero.dk/wp-content/uploads/2014/03/S6-edge-2200-266x300.png" style=""></span> <span class="brand-box-title">Galaxy S-Serien</span> </a>
# <a class="col m:w1/1 brand-box" href="https://ihero.dk/samsung-galaxy-note-3-2/"> <span class="brand-box-img rocket-lazyload" data-bg="https://ihero.dk/wp-content/uploads/2014/05/samsung-galaxy-note-3.png" style=""></span> <span class="brand-box-title">Galaxy Note-Serien</span> </a>
# <a class="col m:w1/1 brand-box" href="https://ihero.dk/samsung-galaxy-core-plus/"> <span class="brand-box-img rocket-lazyload" data-bg="https://ihero.dk/wp-content/uploads/2014/03/samsung-galAXY-CORE-PLUS-3.png" style=""></span> <span class="brand-box-title">Galaxy XCover-Serien</span> </a>
# <a class="col m:w1/1 brand-box" href="https://ihero.dk/samsung-galaxy-s2/"> <span class="brand-box-img rocket-lazyload" data-bg="https://ihero.dk/wp-content/uploads/2014/03/klar-a3-300x300.png" style=""></span> <span class="brand-box-title">Galaxy A-Serien</span> </a>
# <a class="col m:w1/1 brand-box" href="https://ihero.dk/samsung-galaxy-s4/"> <span class="brand-box-img rocket-lazyload" data-bg="https://ihero.dk/wp-content/uploads/2014/03/ace-4-hvid-300x200.png" style=""></span> <span class="brand-box-title">Galaxy Ace-Serien</span> </a>
# <a class="col m:w1/1 brand-box" href="https://ihero.dk/samsung-galaxy-s3-mini/"> <span class="brand-box-img rocket-lazyload" data-bg="https://ihero.dk/wp-content/uploads/2014/03/diverse.png" style=""></span> <span class="brand-box-title">Diverse Modeller</span> </a>
# {'Galaxy S': 'https://ihero.dk/samsung-galaxy-s5-2/',
#  'Galaxy Note': 'https://ihero.dk/samsung-galaxy-note-3-2/',
#  'Galaxy XCover': 'https://ihero.dk/samsung-galaxy-core-plus/',
#  'Galaxy A': 'https://ihero.dk/samsung-galaxy-s2/',
#  'Galaxy Ace': 'https://ihero.dk/samsung-galaxy-s4/',
#  'Diverse Modeller': 'https://ihero.dk/samsung-galaxy-s3-mini/'}

# %%
def get_phone_serie_reparations(serie_name, serie_url):

    html = urlopen(serie_url)
    soup = BeautifulSoup(html, "html.parser")
    reparation_names = [rep.contents[0] for rep in soup.find_all("td", class_="rep-title")]
    prices =  [price.contents[0] for price in soup.find_all("td", class_="price-field tilbuds-pris")]
    
    # phone_dict = {}
    for reparation_name, price in zip(reparation_names, prices):
        # for each of the reparation names, we check if several models are described in one line
        reparation_name_split = reparation_name.split(serie_name)
        if len(reparation_name_split[0]) > 0:
            # several models described in one line
            phone_names = [(serie_name + x.strip()).replace(serie_name[-1] + serie_name[-1], serie_name[-1]) for x in reparation_name_split[1].split(",")]
            
            for phone_name in phone_names:
                # print(phone_name, price)
                pass
        else:
            phone_name = re.search(serie_name + "(\d{0,2}).? (Plus|PLUS|Mini|Edge|Active|Duos|Neo|Advance|)( \+|\+|)", reparation_name).group(0)
            reparation_name = reparation_name.replace(phone_name, "") 
            print(phone_name, reparation_name, price)
        #    rep_name = reparation_name_split[0]
        #    models = reparation_name_split[1:]
        #    print(rep_name)
        #    print(models[0])

    
    # for (reparation_name, price) in zip(reparation_names, prices):
    #     phone_dict[reparation_name] = price
    # return phone_dict
get_phone_serie_reparations('Galaxy S', 'https://ihero.dk/samsung-galaxy-s5-2/')
# Out:
# Galaxy S10 Plus  Komplet skærm udskiftning 2399,-
# Galaxy S10  Komplet skærm Udskiftning 2375,-
# Galaxy S10E  Komplet skærm Udskiftning 1800,-
# Galaxy S9 PLUS  Komplet skærm udskiftning 2399,-
# Galaxy S9  Komplet skærm udskiftning 2300,-
# Galaxy S8 PLUS  Komplet Skærm Udskiftning 2000,-
# Galaxy S8  Komplet Skærm Udskiftning 1900,-
# Galaxy S7 Edge  Komplet Skærm Udskiftning 1899,-
# Galaxy S7  Komplet Skærm Udskiftning 1399,-
# Galaxy S6 Edge +  Komplet Skærm Udskiftning 1699,-
# Galaxy S6 Edge  Komplet Skærm Udskiftning 2000,-
# Galaxy S6  Komplet Skærm Udskiftning 1499,-
# Galaxy S5  Komplet Skærm Udskiftning 1100,-
# Galaxy S5 Mini  Komplet Skærm Udskiftning 800,-
# Galaxy S5 Neo  Komplet Skærm Udskiftning 1100,-
# Galaxy S5 Active  Komplet Skærm Udskiftning 1300,-
# Galaxy S4 +  Komplet Skærm Udskiftning 1100,-
# Galaxy S4  Komplet Skærm Udskiftning 1299,-
# Galaxy S4 Mini  Komplet Skærm Udskiftning 900,-
# Galaxy S4 Active  Komplet Skærm Udskiftning 1400,-
# Galaxy S3  Komplet Skærm Udskiftning 1000,-
# Galaxy S3 Mini  Komplet Skærm Udskiftning 799,-
# Galaxy S2  Komplet Skærm Udskiftning 1000,-
# Galaxy S +  Komplet Skærm Udskiftning 1100,-
# Galaxy S  Komplet Skærm Udskiftning 1200,-
# Galaxy S Advance  Komplet Skærm Udskiftning 1000,-
# Galaxy S Duos  Glas Udskiftning 600,-

# %%
serie_name = "Galaxy S"
reparation_name = "Galaxy S4 + Komplet Skærm Udskiftning"
# reparation_name = "Galaxy S6 Edge + Komplet Skærm Udskiftning"
re.search(serie_name + "(\d{0,2}).?( |)(Plus|PLUS|Mini|Edge|Active|Duos|Neo|Advance|)( \+|\+|)", reparation_name).group(0)
# Out:
# 'Galaxy S4 +'

# %%
def get_phones_urls(brand_name, brand_url):
    html = urlopen(brand_url)
    soup = BeautifulSoup(html, "html.parser")
    phones_soups = soup.find_all("a", class_="col m:w1/1 brand-box")
    phone_names_urls = {}
    for phone_soup in phones_soups:
        phone_name = phone_soup.find("span", class_="brand-box-title").contents[0]
        url = phone_soup.get("href")
        phone_name = brand_name + " " + phone_name
        phone_names_urls[phone_name] = url
    return phone_names_urls

get_phones_urls("Apple iPhones", "https://ihero.dk/iphone-reparation-2/")
# Out:
# {'Apple iPhones IPhone 11 Pro Max': 'https://ihero.dk/iphone-11-pro-max-reparation/',
#  'Apple iPhones iPhone 11 Pro': 'https://ihero.dk/iphone-11-pro-reparation/',
#  'Apple iPhones iPhone 11': 'https://ihero.dk/iphone-11-reparation/',
#  'Apple iPhones iPhone XS Max': 'https://ihero.dk/iphone-xs-max-2/',
#  'Apple iPhones iPhone XS': 'https://ihero.dk/iphone-xs/',
#  'Apple iPhones iPhone XR': 'https://ihero.dk/iphone-xr/',
#  'Apple iPhones iPhone X': 'https://ihero.dk/iphone-x/',
#  'Apple iPhones iPhone 8 Plus': 'https://ihero.dk/iphone-8-plus/',
#  'Apple iPhones iPhone 8': 'https://ihero.dk/iphone-8/',
#  'Apple iPhones iPhone 7 Plus': 'https://ihero.dk/iphone-7-plus/',
#  'Apple iPhones iPhone 7': 'https://ihero.dk/iphone-7/',
#  'Apple iPhones iPhone 6S Plus': 'https://ihero.dk/iphone-6s-plus/',
#  'Apple iPhones iPhone 6S': 'https://ihero.dk/iphone-6s/',
#  'Apple iPhones iPhone 6 Plus': 'https://ihero.dk/iphone-6-plus/',
#  'Apple iPhones iPhone 6': 'https://ihero.dk/iphone-6-2/',
#  'Apple iPhones iPhone SE 2020': 'https://ihero.dk/iphone-se-2020/',
#  'Apple iPhones iPhone SE': 'https://ihero.dk/iphone-se/',
#  'Apple iPhones iPhone 5S': 'https://ihero.dk/iphone-5s/',
#  'Apple iPhones iPhone 5C': 'https://ihero.dk/iphone-5c-2-2/',
#  'Apple iPhones iPhone 5': 'https://ihero.dk/iphone-5/',
#  'Apple iPhones iPhone 4/4S': 'https://ihero.dk/prisliste-44s/'}

# %%
def get_phone_reparations(phone_url):
    html = urlopen(phone_url)
    soup = BeautifulSoup(html, "html.parser")
    reparation_names = [x.contents[0] for x in soup.find_all("td", class_="rep-title")]
    prices = [x.contents[0] for x in soup.find_all("td", class_="price-field tilbuds-pris")]
    phone_dict = {}
    for (reparation_name, price) in zip(reparation_names, prices):
        phone_dict[reparation_name] = price
    return phone_dict

get_phone_reparations("https://ihero.dk/iphone-11-pro-max-reparation/")
# Out:
# {'Skærm udskiftning': '2399,-',
#  'Skærm beskyttelse': '200,-',
#  'Udskiftning af Bagglas': '1500,-',
#  'Batteri udskiftning': 'IKKE PÅ LAGER,-'}

# %%
brand_urls_dict = get_brands_urls()

repair_cost_dict = {}
for brand, brand_url in brand_urls_dict.items():
    if brand == "Samsung":
        continue
    print(brand, brand_url)
    phone_urls_dict = get_phones_urls(brand, brand_url)
    for phone_item in phone_urls_dict.items():
        phone_name = phone_item[0]
        phone_url = phone_item[1]
        repair_cost_dict[phone_name] = get_phone_reparations(phone_url)
print("done")
# Out:
# Apple iPhones https://ihero.dk/iphone-reparation-2/
# Apple iPads https://ihero.dk/ipad-reparation/
# Apple Mac https://ihero.dk/mac-reparation/
# Huawei https://ihero.dk/huawei/
# Sony https://ihero.dk/sony-reparation/
# One Plus https://ihero.dk/one-plus/
# LG https://ihero.dk/lg-reparation/
# Nokia https://ihero.dk/nokia-reparation/
# PC https://ihero.dk/pc-reparation/
# done

# %%
reparations_names = []
for item in repair_cost_dict.items():
    phone_name = item[0]
    reparations = item[1]
    for reparation in reparations:
        reparations_names.append(reparation)

# %%
def convert_reparation_name(reparation_name):
    reparation_name_transformed = reparation_name
    if re.match("(.*Komplet (S|s)kærm.*)|(.*Glas/ LCD.*)|(.*Glas/LCD.*)|(.*LCD.*)|(.*(S|s)kærm.*)", reparation_name) is not None:
        reparation_name_transformed = "screen"
    if re.match("(.*3G.*)|(.*Antenne.*)", reparation_name) is not None:
        reparation_name_transformed = "3G_4G"
    if re.match(".*Batteri.*", reparation_name) is not None:
        reparation_name_transformed = "battery"
    if re.match("(.*BAGSIDE.*)|(.*Bagside.*)|(.*Bagcover.*)|(.*Bagglas.*)", reparation_name) is not None:
        reparation_name_transformed = "back_frame"
    if re.match("(.*GLAS.*)|(.*Glas.*)", reparation_name) is not None:
        reparation_name_transformed = "glass"
    if re.match(".*Bluetooth.*", reparation_name) is not None:
        reparation_name_transformed = "bluetooth"
    if re.match(".*WIFI.*", reparation_name) is not None:
        reparation_name_transformed = "wifi"
    if re.match("(.*BagKamera.*)|(.*Bagkamera.*)", reparation_name) is not None:
        reparation_name_transformed = "back_camera"
    if re.match(".*Front (K|k)amera.*", reparation_name) is not None:
        reparation_name_transformed = "back_camera"
    if re.match(".*Diagnose.*", reparation_name) is not None:
        reparation_name_transformed = "diagnose"
    if re.match(".*Ladestik.*", reparation_name) is not None:
        reparation_name_transformed = "charging_socket"
    if re.match("(.*Vibrator.*)", reparation_name) is not None:
        reparation_name_transformed = "vibrator"
    if re.match("(.*Tænd/(S|s)luk.*)", reparation_name) is not None:
        reparation_name_transformed = "power_cable"
    if re.match("(.*Volume/(L|l)ydløs.*)|(.*Lydløs.*)", reparation_name) is not None:
        reparation_name_transformed = "volume_button"
    if re.match("(.*Bundhøjtaler.*)|(.*Højtaler.*)|(.*Ørehøjtaler.*)", reparation_name) is not None:
        reparation_name_transformed = "speaker"
    if re.match("(.*Ramme.*)", reparation_name) is not None:
        reparation_name_transformed = "full_frame"
    if re.match("(.*Mikrofon.*)", reparation_name) is not None:
        reparation_name_transformed = "microphone"
    if re.match("(.*Kameralinse.*)", reparation_name) is not None:
        reparation_name_transformed = "camera_lens"
    if re.match("(.*audio.*)|(.*Jackstik.*)", reparation_name) is not None:
        reparation_name_transformed = "audio_port"
    if re.match("(.*(H|h)ome (K|k)nap.*)", reparation_name) is not None:
        reparation_name_transformed = "home_button"
    if re.match("(.*Andre knapper.*)", reparation_name) is not None:
        reparation_name_transformed = "other_button"      
    return reparation_name_transformed

# %%
for phone_name, reparations in repair_cost_dict.items():
    for reparation_name, reparation_cost in reparations.copy().items():
        reparations[convert_reparation_name(reparation_name)] = reparations.pop(reparation_name)

# %%
repair_cost_dict
# Out:
# {'Apple iPhones IPhone 11 Pro Max': {'screen': '200,-',
#   'back_frame': '1500,-',
#   'battery': 'IKKE PÅ LAGER,-'},
#  'Apple iPhones iPhone 11 Pro': {'screen': '200,-',
#   'back_frame': '1500,-',
#   'battery': 'IKKE PÅ LAGER,-'},
#  'Apple iPhones iPhone 11': {'screen': '200,-',
#   'back_frame': '1500,-',
#   'battery': 'IKKE PÅ LAGER,-'},
#  'Apple iPhones iPhone XS Max': {'screen': '200,-',
#   'back_frame': '1000,-',
#   'battery': '999,-',
#   'charging_socket': '999,-',
#   'microphone': '999,-',
#   'speaker': '799,-',
#   'back_camera': '1200,-',
#   'camera_lens': '799,-',
#   'power_cable': '999,-',
#   'volume_button': '999,-',
#   'vibrator': '799,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone XS': {'screen': '200,-',
#   'back_frame': '900,-',
#   'battery': '799,-',
#   'charging_socket': '999,-',
#   'microphone': '999,-',
#   'speaker': '799,-',
#   'back_camera': '1200,-',
#   'camera_lens': '799,-',
#   'power_cable': '999,-',
#   'volume_button': '999,-',
#   'vibrator': '799,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone XR': {'screen': '200,-',
#   'back_frame': '900,-',
#   'battery': '799,-',
#   'charging_socket': '999,-',
#   'microphone': '999,-',
#   'speaker': '799,-',
#   'back_camera': '999,-',
#   'camera_lens': '799,-',
#   'power_cable': '999,-',
#   'volume_button': '999,-',
#   'vibrator': '799,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone X': {'screen': '200,-',
#   'back_frame': '900,-',
#   'battery': '799,-',
#   'charging_socket': '999,-',
#   'microphone': '999,-',
#   'speaker': '799,-',
#   'back_camera': '1200,-',
#   'power_cable': '999,-',
#   'volume_button': '999,-',
#   'vibrator': '799,-',
#   'camera_lens': '799,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone 8 Plus': {'screen': '200,-',
#   'back_frame': '800,-',
#   'battery': '399,-',
#   'charging_socket': '699,-',
#   'microphone': '699,-',
#   'speaker': '699,-',
#   'back_camera': '699,-',
#   'power_cable': '699,-',
#   'volume_button': '699,-',
#   'vibrator': '699,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone 8': {'screen': '200,-',
#   'back_frame': '800,-',
#   'battery': '399,-',
#   'charging_socket': '599,-',
#   'microphone': '599,-',
#   'speaker': '599,-',
#   'back_camera': '599,-',
#   'power_cable': '599,-',
#   'volume_button': '599,-',
#   'vibrator': '599,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone 7 Plus': {'screen': '200,-',
#   'battery': '299,-',
#   'speaker': '399,-',
#   'charging_socket': '499,-',
#   'microphone': '499,-',
#   'volume_button': '649,-',
#   'power_cable': '649,-',
#   'back_camera': '749,-',
#   'camera_lens': '399,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone 7': {'screen': '200,-',
#   'battery': '299,-',
#   'speaker': '399,-',
#   'microphone': '449,-',
#   'volume_button': '649,-',
#   'power_cable': '649,-',
#   'charging_socket': '449,-',
#   'back_camera': '499,-',
#   'camera_lens': '399,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone 6S Plus': {'screen': '200,-',
#   'battery': '299,-',
#   'speaker': '349,-',
#   'microphone': '349,-',
#   'volume_button': '449,-',
#   'audio_port': '349,-',
#   'home_button': '349,-',
#   'power_cable': '449,-',
#   'charging_socket': '349,-',
#   'back_camera': '449,-',
#   'camera_lens': '399,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone 6S': {'screen': '200,-',
#   'battery': '299,-',
#   'charging_socket': '349,-',
#   'microphone': '349,-',
#   'audio_port': '349,-',
#   'speaker': '349,-',
#   'volume_button': '449,-',
#   'power_cable': '449,-',
#   'home_button': '349,-',
#   'back_camera': '349,-',
#   'camera_lens': '399,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone 6 Plus': {'screen': '200,-',
#   'battery': '299,-',
#   'speaker': '349,-',
#   'microphone': '349,-',
#   'volume_button': '449,-',
#   'audio_port': '349,-',
#   'home_button': '349,-',
#   'power_cable': '449,-',
#   'charging_socket': '349,-',
#   'back_camera': '349,-',
#   'camera_lens': '299,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone 6': {'screen': '200,-',
#   'battery': '299,-',
#   'charging_socket': '299,-',
#   'microphone': '299,-',
#   'audio_port': '299,-',
#   'speaker': '299,-',
#   'volume_button': '399,-',
#   'power_cable': '399,-',
#   'home_button': '299,-',
#   'back_camera': '299,-',
#   'camera_lens': '299,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone SE 2020': {'screen': '200,-',
#   'back_frame': '1000,-',
#   'battery': '499,-',
#   'charging_socket': '599,-',
#   'microphone': '599,-',
#   'speaker': '599,-',
#   'back_camera': '700,-',
#   'power_cable': '800,-',
#   'volume_button': '800,-',
#   'vibrator': '400,-',
#   'diagnose': 'GRATIS,-'},
#  'Apple iPhones iPhone SE': {'screen': '150,-',
#   'battery': '299,-',
#   'microphone': '299,-',
#   'home_button': '299,-',
#   'back_camera': '299,-',
#   'power_cable': '299,-',
#   'charging_socket': '299,-',
#   'volume_button': '299,-',
#   'speaker': '299,-',
#   'audio_port': '299,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone 5S': {'screen': '150,-',
#   'battery': '299,-',
#   'charging_socket': '299,-',
#   'microphone': '299,-',
#   'home_button': '299,-',
#   'back_camera': '299,-',
#   'power_cable': '299,-',
#   'volume_button': '299,-',
#   'speaker': '299,-',
#   'audio_port': '299,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone 5C': {'screen': '150,-',
#   'battery': '299,-',
#   'charging_socket': '299,-',
#   'speaker': '299,-',
#   'audio_port': '299,-',
#   'microphone': '299,-',
#   'home_button': '299,-',
#   'back_camera': '299,-',
#   'power_cable': '299,-',
#   'volume_button': '299,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone 5': {'screen': '150,-',
#   'battery': '299,-',
#   'home_button': '299,-',
#   'back_camera': '299,-',
#   'microphone': '299,-',
#   'charging_socket': '299,-',
#   'audio_port': '299,-',
#   'power_cable': '299,-',
#   'volume_button': '299,-',
#   'speaker': '299,-',
#   'vibrator': '299,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPhones iPhone 4/4S': {'screen': '100,-',
#   'battery': '199,-',
#   'home_button': '250,-',
#   'other_button': '250,-',
#   'microphone': '225,-',
#   'back_camera': '250,-',
#   'charging_socket': '225,-',
#   'vibrator': '200,-',
#   'audio_port': '250,-',
#   '3G_4G': '220,-',
#   'full_frame': '350,-',
#   'wifi': '220,-',
#   'speaker': '200,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads IPad 2': {'glass': '299,-',
#   'screen': '499,-',
#   'battery': '549,-',
#   'audio_port': '499,-',
#   '3G_4G': '499,-',
#   'wifi': '499,-',
#   'charging_socket': '499,-',
#   'speaker': '499,-',
#   'volume_button': '499,-',
#   'home_button': '499,-',
#   'bluetooth': '499,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad 3': {'glass': '349,-',
#   'screen': '599,-',
#   'audio_port': '499,-',
#   '3G_4G': '499,-',
#   'wifi': '499,-',
#   'charging_socket': '499,-',
#   'speaker': '499,-',
#   'volume_button': '499,-',
#   'battery': '649,-',
#   'home_button': '499,-',
#   'bluetooth': '499,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad 4': {'glass': '349,-',
#   'screen': '599,-',
#   'battery': '649,-',
#   'audio_port': '499,-',
#   '3G_4G': '499,-',
#   'wifi': '499,-',
#   'charging_socket': '499,-',
#   'speaker': '499,-',
#   'volume_button': '499,-',
#   'home_button': '499,-',
#   'bluetooth': '499,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad Air': {'glass': '399,-',
#   'screen': '799,-',
#   'audio_port': '649,-',
#   '3G_4G': '649,-',
#   'wifi': '649,-',
#   'charging_socket': '999,-',
#   'speaker': '649,-',
#   'volume_button': '649,-',
#   'battery': '649,-',
#   'home_button': '649,-',
#   'bluetooth': '649,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad Air 2': {'screen': '200,-',
#   'battery': '899,-',
#   'audio_port': '699,-',
#   '3G_4G': '699,-',
#   'wifi': '699,-',
#   'charging_socket': '999,-',
#   'speaker': '699,-',
#   'volume_button': '699,-',
#   'home_button': '699,-',
#   'bluetooth': '699,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad Air 2019': {'screen': '1799,-'},
#  'Apple iPads iPad 9,7 2017': {'glass': '599,-',
#   'screen': '999,-',
#   'audio_port': '799,-',
#   '3G_4G': '799,-',
#   'wifi': '799,-',
#   'charging_socket': '999,-',
#   'speaker': '799,-',
#   'volume_button': '799,-',
#   'battery': '799,-',
#   'home_button': '799,-',
#   'bluetooth': '799,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad 9,7 2018': {'glass': '699,-',
#   'screen': '999,-',
#   'battery': '599,-',
#   'charging_socket': '999,-'},
#  'Apple iPads iPad Mini 1-2': {'glass': '499,-',
#   'screen': '699,-',
#   'battery': '699,-',
#   'audio_port': '499,-',
#   '3G_4G': '499,-',
#   'wifi': '499,-',
#   'charging_socket': '999,-',
#   'speaker': '499,-',
#   'volume_button': '499,-',
#   'home_button': '699,-',
#   'bluetooth': '499,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad Mini 3': {'glass': '599,-',
#   'screen': '699,-',
#   'battery': '699,-',
#   'audio_port': '699,-',
#   '3G_4G': '699,-',
#   'wifi': '699,-',
#   'charging_socket': '999,-',
#   'speaker': '699,-',
#   'volume_button': '699,-',
#   'home_button': '699,-',
#   'bluetooth': '699,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad Mini 4': {'screen': '200,-',
#   'back_frame': '1499,-',
#   'audio_port': '749,-',
#   '3G_4G': '749,-',
#   'wifi': '749,-',
#   'charging_socket': '999,-',
#   'speaker': '749,-',
#   'volume_button': '749,-',
#   'battery': '749,-',
#   'home_button': '749,-',
#   'bluetooth': '749,-',
#   'diagnose': 'GRATIS'},
#  'Apple iPads iPad Mini 2019': {'screen': '1499,-'},
#  'Apple iPads iPad PRO': {},
#  'Apple iPads iPad 10,2 2019': {'screen': '899,-'},
#  'Apple Mac Macbook Pro': {},
#  'Apple Mac Macbook Pro Retina': {},
#  'Apple Mac MacBook Air 11"': {},
#  'Apple Mac MacBook Air 13"': {},
#  'Apple Mac iMac': {},
#  'Apple Mac iMac Retina/4K/5K': {},
#  'Apple Mac Macbook Pro (Uden Touch Bar)': {},
#  'Apple Mac Macbook Pro (Med Touch Bar)': {},
#  'Apple Mac Macbook 12"': {},
#  'Huawei Huawei P30 Pro': {'screen': '2800,-'},
#  'Huawei Huawei P30': {'screen': '1299,-'},
#  'Huawei Huawei P30 Lite': {'screen': '999,-'},
#  'Huawei Huawei Mate 20 Pro': {'screen': '3499,-'},
#  'Huawei Huawei P20 Pro': {'glass': '2300,-',
#   'back_frame': '699,-',
#   'battery': 'IKKE PÅ LAGER,-'},
#  'Huawei Huawei Mate 20 Lite': {'screen': '1500,-'},
#  'Huawei Huawei P20 Lite': {'glass': '799,-',
#   'back_frame': '599,-',
#   'battery': '499,-'},
#  'Huawei Huawei P20': {'glass': '899,-', 'back_frame': '599,-'},
#  'Huawei Huawei Mate 10 Pro': {'glass': '2499,-'},
#  'Huawei Huawei Mate 9 Pro': {'glass': '3000,-'},
#  'Huawei Huawei P10 Plus': {'glass': '1400,-',
#   'back_frame': '1000,-',
#   'battery': '500,-'},
#  'Huawei Huawei P9 Plus': {'glass': '1700,-',
#   'back_frame': '700,-',
#   'battery': '500,-'},
#  'Huawei Huawei P10 Lite': {'glass': '799,-',
#   'back_frame': '500,-',
#   'battery': '500,-'},
#  'Huawei Huawei P10': {'glass': '949,-',
#   'back_frame': '700,-',
#   'battery': '500,-'},
#  'Huawei Huawei Mate 10 Lite': {'glass': '799,-'},
#  'Huawei Huawei Mate 10': {'glass': '1099,-'},
#  'Huawei Huawei P9 Lite': {'glass': '749,-',
#   'back_frame': '500,-',
#   'battery': '500,-'},
#  'Huawei Huawei P9': {'glass': '899,-',
#   'back_frame': '600,-',
#   'battery': '600,-'},
#  'Huawei Huawei Honor 9 Lite': {'glass': '849,-'},
#  'Huawei Huawei Honor 9': {'glass': '1699,-'},
#  'Huawei Huawei P8 Lite': {'glass': '750,-',
#   'back_frame': '500,-',
#   'battery': '500,-'},
#  'Huawei Huawei P8': {'glass': '750,-',
#   'back_frame': '500,-',
#   'battery': '500,-'},
#  'Huawei Huawei P Smart 2019': {'screen': '899,-'},
#  'Huawei Huawei P-Smart': {'screen': '799,-'},
#  'Huawei Huawei Y6 2019': {'screen': '1000,-'},
#  'Huawei Huawei Y5 2019': {'screen': '1100,-'},
#  'Huawei Huawei P Smart Z': {'screen': '1300,-'},
#  'Sony Xperia Z5 Premium': {'screen': '2000,-'},
#  'Sony Xperia Z5 Compact': {'glass': '1199,-', 'back_frame': '500,-'},
#  'Sony Xperia Z5': {'glass': '1500,-', 'back_frame': '500,-'},
#  'Sony Xperia Z4 (Z3+)': {'glass': '1499,-', 'back_frame': '500,-'},
#  'Sony Xperia Z3 Compact': {'glass': '999,-',
#   'back_frame': '399,-',
#   'diagnose': 'GRATIS'},
#  'Sony Xperia Z3': {'glass': '1199,-',
#   'back_frame': '399,-',
#   'diagnose': 'GRATIS'},
#  'Sony Xperia Z2': {'glass': '999,-',
#   'back_frame': '399,-',
#   'diagnose': 'GRATIS'},
#  'Sony Xperia Z1 Compact': {'glass': '800,-',
#   'back_frame': '399,-',
#   'diagnose': 'GRATIS'},
#  'Sony Xperia Z1': {'screen': '849,-',
#   'back_frame': '399,-',
#   'diagnose': 'GRATIS'},
#  'Sony Xperia Z': {'screen': '849,-',
#   'back_frame': '399,-',
#   'diagnose': 'GRATIS'},
#  'Sony Xperia Z Ultra': {'screen': '2200,-'},
#  'Sony Diverse Modeller': {'screen': '800,-', 'glass': '600,-'},
#  'Sony X-Serien': {'screen': '1000,-'},
#  'Sony M-Serie': {'glass': '800,-', 'screen': '1200,-'},
#  'One Plus OnePlus 7 Pro': {'screen': '3500,-'},
#  'One Plus OnePlus 7': {'screen': '2500,-'},
#  'One Plus OnePlus 6T': {'screen': '2000,-', 'back_frame': '700,-'},
#  'One Plus OnePlus 6': {'screen': '1799,-', 'back_frame': '699,-'},
#  'One Plus OnePlus 5T': {'screen': '1399,-', 'battery': '700,-'},
#  'One Plus OnePlus 5': {'screen': '1199,-', 'battery': '600,-'},
#  'One Plus OnePlus 3T': {'screen': '1249,-', 'battery': '600,-'},
#  'One Plus OnePlus 3': {'glass': '1249,-'},
#  'One Plus OnePlus 2': {'glass': '849,-', 'diagnose': 'GRATIS'},
#  'One Plus OnePlus One': {'glass': '849,-',
#   'charging_socket': '600,-',
#   'diagnose': 'GRATIS'},
#  'One Plus OnePlus X': {'glass': '1199,-'},
#  'LG LG G6': {'glass': '1500,-'},
#  'LG LG G5': {'screen': '2000,-'},
#  'LG LG G4S': {'screen': '1000,-'},
#  'LG LG G4': {'glass': '1100,-', 'diagnose': 'GRATIS'},
#  'LG LG G3S': {'glass': '800,-'},
#  'LG LG G3': {'glass': '1000,-', 'diagnose': 'GRATIS'},
#  'LG LG G2': {'screen': '950,-', 'diagnose': 'GRATIS'},
#  'LG LG G2 MINI': {'glass': '700,-', 'screen': '900,-', 'diagnose': 'GRATIS'},
#  'LG LG Nexus 5X': {'screen': '1200,-'},
#  'LG LG (GOOGLE) NEXUS 5': {'screen': '1200,-', 'diagnose': 'GRATIS'},
#  'LG LG (GOOGLE) NEXUS 4': {'screen': '1100,-', 'diagnose': 'GRATIS'},
#  'LG LG G FLEX 2': {'glass': '1800,-', 'diagnose': 'GRATIS'},
#  'LG LG G Flex': {'glass': '1700,-', 'diagnose': 'GRATIS'},
#  'LG LG OPTIMUS G': {'screen': '950,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 1520': {'glass': '1200,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 1320': {'glass': '1500,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 1020': {'glass': '1000,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 935': {'glass': '1800,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 930': {'glass': '1800,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 920': {'glass': '600,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 900': {'screen': '1200,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 830': {'glass': '1600,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 820': {'screen': '1200,-',
#   'glass': '700,-',
#   'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 800': {'screen': '800,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 735': {'glass': '800,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 730': {'glass': '800,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 720': {'glass': '1200,-', 'diagnose': 'GRATIS'},
#  'Nokia Nokia Lumia 710': {'glass': '800,-',
#   'screen': '800,-',
#   'diagnose': 'GRATIS'}}
